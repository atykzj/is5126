# %% [markdown]
# ### Update 14/11
# ##### Methods are based on https://github.com/Shitao-zz/Kaggle-House-Prices-Advanced-Regression-Techniques and this https://www.kaggle.com/niteshx2/top-50-beginners-stacking-lgb-xgb
# - Add a new feature on [popular primary schools](https://www.moe.gov.sg/primary/p1-registration/distance) priority is given to people living < 2 km near these schools. Chosen primary schools are based on [oversubscribed rates](https://www.salary.sg/2022/best-primary-schools-2022-by-popularity/)
# - - Secondary school is based on scores not based on living distance so we ignore.
#
# Update Preprocessing
# - - - Drop: Planning area variables cannot really explain. area_size(of planning area does not really explain), population(of planning area).
# - - Dropping outliers, unimportant features, handle categorical features, log transform skewed variables.
# - - Furnishing keep 3 values, Fully furnished, partially, unfurnished
# - - 'region' there is 'geyland' value
#
# Model Training
# - - Random forest, xgboost, lightgbm.
# - - Level 1: StackingCVRegressor,
#
# FINAL Variables
# - 'property_type', 'tenure', 'built_year', 'num_beds', 'num_baths',
#        'furnishing', 'available_unit_types', 'total_num_units', 'cc_distance',
#        'mrt_distance', 'shop_distance', 'population', 'log_size_sqft',
#        'region', 'near_top_ps', 'secondary_school_distance'

# %% [markdown]
# ### TO DO
# - Explain that we are removing 'landed'. EDA need show why landed can skew data
# - Explain why we need to normalise price, is because we want to achieve ['Homoscedasticity'](https://www.kaggle.com/code/pmarcelino/comprehensive-data-exploration-with-python#5.-Getting-hard-core)
# - Double check distances calculation when merge with planning_area, serangoon planning area is way too big, might miss some places
# - Remove single charts, summarise the code
# - Markdown each section clearly (#, ##, ###)
# - Standardise coding formats (variable names, function names)
# - EDA do not do preprocessing. In EDA just note what kind of missing values and suggested replacement values. Move all preprocessing into the section 2.
# - - Do not drop any columns until the 2nd section
#
# - - For each Numerical column we can apply log so that it will all have normal distribution so that it can correlate properly with log_price.
#
# ```
# #histogram and normal probability plot
# sns.distplot(train['price'], fit=norm);
# fig = plt.figure()
# res = stats.probplot(train['price'], plot=plt)
# ```
#
# - Create Table of contents
# Suggested Table of Contents
# 1. EDA
# 2. Mining & Data Preprocessing
# 3. Modelling
#
# ##### Notes:
# - Do not need to add inflation or housing price growth because these two variables are built into housing prices.
# - What is total_num_units?

# %% [markdown]
# ### 4 Statistical assumptions why we do any of the preprocessing or EDA
# According to [Hair et al. (2013)](https://amzn.to/2uC3j9p), four assumptions should be tested:
#
# Normality - When we talk about normality what we mean is that the data should look like a normal distribution. This is important because several statistic tests rely on this (e.g. t-statistics). In this exercise we'll just check univariate normality for 'SalePrice' (which is a limited approach). Remember that univariate normality doesn't ensure multivariate normality (which is what we would like to have), but it helps. Another detail to take into account is that in big samples (>200 observations) normality is not such an issue. However, if we solve normality, we avoid a lot of other problems (e.g. heteroscedacity) so that's the main reason why we are doing this analysis.
#
# Homoscedasticity - I just hope I wrote it right. Homoscedasticity refers to the 'assumption that dependent variable(s) exhibit equal levels of variance across the range of predictor variable(s)' ([Hair et al. (2013)](https://amzn.to/2uC3j9p)). Homoscedasticity is desirable because we want the error term to be the same across all values of the independent variables.
#
# Linearity- The most common way to assess linearity is to examine scatter plots and search for linear patterns. If patterns are not linear, it would be worthwhile to explore data transformations. However, we'll not get into this because most of the scatter plots we've seen appear to have linear relationships.
#
# Absence of correlated errors - Correlated errors, like the definition suggests, happen when one error is correlated to another. For instance, if one positive error makes a negative error systematically, it means that there's a relationship between these variables. This occurs often in time series, where some patterns are time related. We'll also not get into this. However, if you detect something, try to add a variable that can explain the effect you're getting. That's the most common solution for correlated errors.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import statistics as st 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, plot_confusion_matrix

from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler, RobustScaler
from sklearn.compose import make_column_selector
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import RidgeCV, LassoCV, ElasticNetCV, Ridge, Lasso, ElasticNet
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score

from xgboost.sklearn import XGBRegressor
import lightgbm as lgb
from sklearn.ensemble import StackingRegressor
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_transformer

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import make_scorer, mean_squared_error
from math import sqrt
import seaborn as sns

from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
# import category_encoders as ce
import datetime

# %%
# !pip install mlxtend
from mlxtend.regressor import StackingCVRegressor

# %% [markdown]
# # EDA

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %% [markdown]
# #### planning_area & subzone NA value in test dataset

# %%
train
# Out:
#        listing_id                                              title  \
# 0          122881          hdb flat for sale in 866 yishun street 81
# 1          259374  hdb flat for sale in 506b serangoon north aven...
# 2          665422                 4 bed condo for sale in meyerhouse
# 3          857699               3 bed condo for sale in leedon green
# 4          216061                 2 bed condo for sale in one bernam
# ...           ...                                                ...
# 20249      345066              2 bed condo for sale in lentor modern
# 20250      868680                       2 bed condo for sale in mori
# 20251      928187  4 bed condo for sale in pullman residences newton
# 20252      135122       hdb flat for sale in 691d woodlands drive 73
# 20253      376579  4 bed condo for sale in pullman residences newton
#
#                                   address              property_name  \
# 0                sembawang / yishun (d27)       866 yishun street 81
# 1      hougang / punggol / sengkang (d19)       hdb-serangoon estate
# 2                          128 meyer road                 meyerhouse
# 3                       26 leedon heights               leedon green
# 4                         1 bernam street                 one bernam
# ...                                   ...                        ...
# 20249                      lentor central              lentor modern
# 20250                 223 guillemard road                       mori
# 20251                     18 dunearn road  pullman residences newton
# 20252         admiralty / woodlands (d25)            admiralty flora
# 20253                     18 dunearn road  pullman residences newton
#
#       property_type             tenure  built_year  num_beds  num_baths  \
# 0       hdb 4 rooms                NaN      1988.0       3.0        2.0
# 1               hdb  99-year leasehold      1992.0       4.0        2.0
# 2             condo           freehold      2022.0       4.0        6.0
# 3             Condo           freehold      2023.0       3.0        2.0
# 4             condo  99-year leasehold      2026.0       2.0        1.0
# ...             ...                ...         ...       ...        ...
# 20249         condo  99-year leasehold      2026.0       2.0        2.0
# 20250         Condo           freehold      2026.0       2.0        2.0
# 20251         condo           freehold      2023.0       4.0        4.0
# 20252   hdb 5 rooms  99-year leasehold      2017.0       3.0        2.0
# 20253         condo           freehold      2023.0       4.0        4.0
#
#        size_sqft  ...   furnishing      available_unit_types total_num_units  \
# 0           1115  ...  unspecified                       NaN           116.0
# 1           1575  ...  unspecified       1, 2, 3, 4, 5, 6 br             NaN
# 2           3070  ...      partial     studio, 3, 4, 5, 6 br            56.0
# 3            958  ...      partial     studio, 1, 2, 3, 4 br           638.0
# 4            732  ...  unspecified  studio, 1, 2, 3, 4, 5 br           351.0
# ...          ...  ...          ...                       ...             ...
# 20249        635  ...  unspecified             1, 2, 3, 4 br           605.0
# 20250        883  ...  unspecified             1, 2, 3, 4 br           137.0
# 20251       1378  ...  unspecified  studio, 1, 2, 3, 4, 5 br           340.0
# 20252       1205  ...  unfurnished                2, 3, 4 br           402.0
# 20253       1378  ...      partial  studio, 1, 2, 3, 4, 5 br           340.0
#
#                                     property_details_url       lat  \
# 0      https://www.99.co/singapore/hdb/866-yishun-str...  1.414399
# 1      https://www.99.co/singapore/hdb/hdbserangoon-e...  1.372597
# 2      https://www.99.co/singapore/condos-apartments/...  1.298773
# 3      https://www.99.co/singapore/condos-apartments/...  1.312364
# 4      https://www.99.co/singapore/condos-apartments/...  1.273959
# ...                                                  ...       ...
# 20249  https://www.99.co/singapore/condos-apartments/...  1.385938
# 20250  https://www.99.co/singapore/condos-apartments/...  1.315948
# 20251  https://www.99.co/singapore/condos-apartments/...  1.315961
# 20252  https://www.99.co/singapore/hdb/admiralty-flor...  1.440753
# 20253  https://www.99.co/singapore/condos-apartments/...  1.315961
#
#               lng  elevation          subzone  planning_area      price
# 0      103.837196          0     yishun south         yishun   514500.0
# 1      103.875625          0  serangoon north      serangoon   995400.0
# 2      103.895798          0      mountbatten  marine parade  8485000.0
# 3      103.803271          0     farrer court    bukit timah  2626000.0
# 4      103.843635          0            anson  downtown core  1764000.0
# ...           ...        ...              ...            ...        ...
# 20249  103.834466          0           tagore     ang mo kio  1050000.0
# 20250  103.857589          0         lavender        kallang  2087400.0
# 20251  103.836848          0         moulmein         novena  4193700.0
# 20252  103.806671          0   woodlands east      woodlands   754800.0
# 20253  103.836848          0         moulmein         novena  4178000.0
#
# [20254 rows x 21 columns]

# %%
len(train[train['built_year'] >= 2020])
# Out:
# 8252

# %%
train['built_year'].nunique()
# Out:
# 63

# %% [markdown]
# train['built_year']

# %%
emptyPA = test[test['planning_area'].isna()]
emptyPA['address'].unique()
# Out:
# array(['1 tessensohn road', '38 lorong 32 geylang', '17 farrer drive',
#        '5 jalan mutiara'], dtype=object)

# %%
missingPA = pd.read_csv('auxiliary-data/missingPAdata.csv')
missingPA.head()
# Out:
#                 address planning_area     subzone
# 0     1 tessensohn road       kallang   boon keng
# 1  38 lorong 32 geylang       geyland    aljunied
# 2       15 farrer drive       tanglin  chatsworth
# 3       17 farrer drive       tanglin  chatsworth
# 4       5 jalan mutiara       tanglin      nassim

# %%
s = missingPA.set_index('address')['planning_area']
test['planning_area']=test['planning_area'].fillna(test['address'].map(s))

# %%
s = missingPA.set_index('address')['subzone']
test['subzone']=test['planning_area'].fillna(test['subzone'].map(s))

# %%
test.count()
# Out:
# listing_id              6966
# title                   6966
# address                 6964
# property_name           6966
# property_type           6966
# tenure                  6329
# built_year              6608
# num_beds                6931
# num_baths               6817
# size_sqft               6966
# floor_level             1156
# furnishing              6966
# available_unit_types    6446
# total_num_units         5066
# property_details_url    6966
# lat                     6966
# lng                     6966
# elevation               6966
# subzone                 6966
# planning_area           6966
# dtype: int64

# %% [markdown]
# #### planning & subzone in train dataset

# %%
data = train[train['planning_area'].isna()]
data['address'].unique()
# Out:
# array(['1 tessensohn road', '15 farrer drive', '17 farrer drive',
#        '38 lorong 32 geylang', '5 jalan mutiara'], dtype=object)

# %%
s = missingPA.set_index('address')['planning_area']
train['planning_area']=train['planning_area'].fillna(train['address'].map(s))

# %%
s = missingPA.set_index('address')['subzone']
train['subzone']=train['planning_area'].fillna(train['subzone'].map(s))

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# ### Remove listing_id
# #### listing_id is all unique without duplicates

# %%
train.describe()
# Out:
#           listing_id    built_year      num_beds     num_baths     size_sqft  \
# count   20254.000000  19332.000000  20174.000000  19820.000000  2.025400e+04
# mean   550763.206428   2010.833695      3.122931      2.643542  1.854364e+03
# std    258874.420108     15.822803      1.281658      1.473835  1.354343e+04
# min    100043.000000   1963.000000      1.000000      1.000000  0.000000e+00
# 25%    326279.000000   2000.000000      2.000000      2.000000  8.070000e+02
# 50%    551397.000000   2017.000000      3.000000      2.000000  1.119000e+03
# 75%    774044.500000   2023.000000      4.000000      3.000000  1.528000e+03
# max    999944.000000   2028.000000     10.000000     10.000000  1.496000e+06
#
#        total_num_units           lat           lng  elevation         price
# count     14602.000000  20254.000000  20254.000000    20254.0  2.025400e+04
# mean        376.253938      1.434282    103.855356        0.0  5.228263e+06
# std         346.882474      1.558472      3.593441        0.0  2.779748e+08
# min           4.000000      1.239621    -77.065364        0.0  0.000000e+00
# 25%         106.000000      1.307329    103.806576        0.0  8.190000e+05
# 50%         296.000000      1.329266    103.841552        0.0  1.680000e+06
# 75%         561.000000      1.372461    103.881514        0.0  3.242400e+06
# max        2612.000000     69.486768    121.023232        0.0  3.924243e+10

# %% [markdown]
# ### Adding Distances

# %% [markdown]
# #### Add distance to commericial centres

# %%
ccdistance = pd.read_csv('auxiliary-data/sg-commerical-centres.csv')

# %%
# vectorized haversine function
#https://stackoverflow.com/questions/29545704/fast-haversine-approximation-python-pandas
def haversine_np(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)

    All args must be of equal length.    

    """
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2

    c = 2 * np.arcsin(np.sqrt(a))
    km = 6367 * c
    return km

# %%
# train['cc_distance'] = haversine_np(train['lng'], train['lat'], ccdistance['lng'], ccdistance['lat'])
expected_result = pd.merge(train, ccdistance, on = 'planning_area')
expected_result.head()
train['cc_distance'] = haversine_np(train['lng'], train['lat'], expected_result['lng_y'], expected_result['lat_y'])

# train['cc_distance'] = haversine_np(train['lng'], train['lat'], ccdistance['lng'], ccdistance['lat'])
expected_result = pd.merge(test, ccdistance, on = 'planning_area')
expected_result.head()
test['cc_distance'] = haversine_np(test['lng'], test['lat'], expected_result['lng_y'], expected_result['lat_y'])

# %%
ccdistancemean = train['cc_distance'].median()
train['cc_distance']=train['cc_distance'].fillna(ccdistancemean)

ccdistancemean = test['cc_distance'].median()
test['cc_distance']=test['cc_distance'].fillna(ccdistancemean)

# %%
# Creating plot
sns.boxplot(train['cc_distance'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cc_distance'>

# %%
train.loc[train['cc_distance'] > 2000, 'cc_distance'] = train['cc_distance'].median()
# Creating plot
sns.boxplot(train['cc_distance'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cc_distance'>

# %%
train.loc[train['cc_distance'] > 21, 'cc_distance'] = 21
# Creating plot
sns.boxplot(train['cc_distance'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cc_distance'>

# %%
test.loc[test['cc_distance'] > 21, 'cc_distance'] = 21

# %%
sns.boxplot(test['cc_distance'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cc_distance'>

# %% [markdown]
# #### Add distance to mrt stations

# %%
# using long and lat
mrtdistance = pd.read_csv('auxiliary-data/sg-mrt-stations.csv')
expected_result = pd.merge(train, mrtdistance, on = 'planning_area')
train['mrt_distance'] = haversine_np(train['lng'], train['lat'], expected_result['lng_y'], expected_result['lat_y'])


# using long and lat
mrtdistance = pd.read_csv('auxiliary-data/sg-mrt-stations.csv')
expected_result = pd.merge(test, mrtdistance, on = 'planning_area')
test['mrt_distance'] = haversine_np(test['lng'], test['lat'], expected_result['lng_y'], expected_result['lat_y'])

# %%
mrtdistancemedian = train['mrt_distance'].median()
train['mrt_distance']=train['mrt_distance'].fillna(mrtdistancemedian)

mrtdistancemedian = test['mrt_distance'].median()
test['mrt_distance']=test['mrt_distance'].fillna(mrtdistancemedian)

# %%
sns.boxplot(train['mrt_distance'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mrt_distance'>

# %%
train.loc[train['mrt_distance'] > 2000, 'mrt_distance'] = train['mrt_distance'].median()
# Creating plot
sns.boxplot(train['mrt_distance'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mrt_distance'>

# %%
train.loc[train['mrt_distance'] > 22, 'mrt_distance'] = 22
# Creating plot
sns.boxplot(train['mrt_distance'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mrt_distance'>

# %%
test.loc[test['mrt_distance'] > 2000, 'mrt_distance'] = test['mrt_distance'].median()

# %%
sns.boxplot(test['mrt_distance'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mrt_distance'>

# %% [markdown]
# #### Add distance to primary school

# %%
# using long and lat
primaryschooldistance = pd.read_csv('auxiliary-data/sg-primary-schools.csv')
expected_result = pd.merge(train, primaryschooldistance, on = 'planning_area')
train['primary_school_distance'] = haversine_np(train['lng'], train['lat'], expected_result['lng_y'], expected_result['lat_y'])

# using long and lat
primaryschooldistance = pd.read_csv('auxiliary-data/sg-primary-schools.csv')
expected_result = pd.merge(test, primaryschooldistance, on = 'planning_area')
test['primary_school_distance'] = haversine_np(test['lng'], test['lat'], expected_result['lng_y'], expected_result['lat_y'])

# %%
pschoolmedian = train['primary_school_distance'].median()
train['primary_school_distance'] = train['primary_school_distance'].fillna(pschoolmedian)

pschoolmedian = test['primary_school_distance'].median()
test['primary_school_distance'] = test['primary_school_distance'].fillna(pschoolmedian)

# %%
train.loc[train['primary_school_distance'] > 26, 'primary_school_distance'] = 26
sns.boxplot(train['primary_school_distance'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='primary_school_distance'>

# %%
test.loc[test['primary_school_distance'] > 26, 'primary_school_distance'] = 26

# %%
sns.boxplot(test['primary_school_distance'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='primary_school_distance'>

# %% [markdown]
# #### Add distance to secondary school

# %%
# using long and lat
secschooldistance = pd.read_csv('auxiliary-data/sg-secondary-schools.csv')
expected_result = pd.merge(train, secschooldistance, on = 'planning_area')
train['secondary_school_distance'] = haversine_np(train['lng'], train['lat'], expected_result['lng_y'], expected_result['lat_y'])

# using long and lat
secschooldistance = pd.read_csv('auxiliary-data/sg-secondary-schools.csv')
expected_result = pd.merge(test, secschooldistance, on = 'planning_area')
test['secondary_school_distance'] = haversine_np(test['lng'], test['lat'], expected_result['lng_y'], expected_result['lat_y'])

# %%
sschooldistance = train['secondary_school_distance'].median()
train['secondary_school_distance'] = train['secondary_school_distance'].fillna(sschooldistance)

sschooldistance = test['secondary_school_distance'].median()
test['secondary_school_distance'] = test['secondary_school_distance'].fillna(sschooldistance)

# %%
train.loc[train['secondary_school_distance'] > 24, 'secondary_school_distance'] = 24
sns.boxplot(train['secondary_school_distance'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='secondary_school_distance'>

# %%
test.loc[test['secondary_school_distance'] > 24, 'secondary_school_distance'] = 24
sns.boxplot(test['secondary_school_distance'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='secondary_school_distance'>

# %% [markdown]
# #### Add distance to shopping malls

# %%
# using long and lat
shop_distance = pd.read_csv('auxiliary-data/sg-shopping-malls.csv')
expected_result = pd.merge(train, secschooldistance, on = 'planning_area')
train['shop_distance'] = haversine_np(train['lng'], train['lat'], expected_result['lng_y'], expected_result['lat_y'])

# using long and lat
shop_distance = pd.read_csv('auxiliary-data/sg-shopping-malls.csv')
expected_result = pd.merge(test, secschooldistance, on = 'planning_area')
test['shop_distance'] = haversine_np(test['lng'], test['lat'], expected_result['lng_y'], expected_result['lat_y'])

# %%
sdistancemedian = train['shop_distance'].median()
train['shop_distance'] = train['shop_distance'].fillna(sdistancemedian)

sdistancemedian = test['shop_distance'].median()
test['shop_distance'] = test['shop_distance'].fillna(sdistancemedian)

# %%
train.loc[train['shop_distance'] > 2000, 'shop_distance'] = train['shop_distance'].median()
sns.boxplot(train['shop_distance'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='shop_distance'>

# %%
train.loc[train['shop_distance'] > 24, 'shop_distance'] = 24
sns.boxplot(train['shop_distance'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='shop_distance'>

# %%
test.loc[test['shop_distance'] > 24, 'shop_distance'] = 24

# %% [markdown]
# ### lng & lat

# %%
train.head()
# Out:
#    listing_id                                              title  \
# 0      122881          hdb flat for sale in 866 yishun street 81
# 1      259374  hdb flat for sale in 506b serangoon north aven...
# 2      665422                 4 bed condo for sale in meyerhouse
# 3      857699               3 bed condo for sale in leedon green
# 4      216061                 2 bed condo for sale in one bernam
#
#                               address         property_name property_type  \
# 0            sembawang / yishun (d27)  866 yishun street 81   hdb 4 rooms
# 1  hougang / punggol / sengkang (d19)  hdb-serangoon estate           hdb
# 2                      128 meyer road            meyerhouse         condo
# 3                   26 leedon heights          leedon green         Condo
# 4                     1 bernam street            one bernam         condo
#
#               tenure  built_year  num_beds  num_baths  size_sqft  ...  \
# 0                NaN      1988.0       3.0        2.0       1115  ...
# 1  99-year leasehold      1992.0       4.0        2.0       1575  ...
# 2           freehold      2022.0       4.0        6.0       3070  ...
# 3           freehold      2023.0       3.0        2.0        958  ...
# 4  99-year leasehold      2026.0       2.0        1.0        732  ...
#
#           lng elevation        subzone  planning_area      price  cc_distance  \
# 0  103.837196         0         yishun         yishun   514500.0     8.027727
# 1  103.875625         0      serangoon      serangoon   995400.0     2.400374
# 2  103.895798         0  marine parade  marine parade  8485000.0     6.389766
# 3  103.803271         0    bukit timah    bukit timah  2626000.0     8.802339
# 4  103.843635         0  downtown core  downtown core  1764000.0     9.160635
#
#    mrt_distance  primary_school_distance secondary_school_distance  \
# 0      1.689357                 5.178683                  2.538065
# 1      6.871207                 8.310177                  6.710202
# 2     13.983476                 9.485153                 15.197137
# 3     13.479646                 3.290085                 12.950660
# 4     15.981982                13.818954                 17.977600
#
#   shop_distance
# 0      2.538065
# 1      6.710202
# 2     15.197137
# 3     12.950660
# 4     17.977600
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Population

# %%
population = pd.read_csv('auxiliary-data/sg-subzones.csv')

# %%
expected_result = pd.merge(train, population, on = 'planning_area')
train['population'] = expected_result['population']
train['area_size'] = expected_result['area_size']

# %%
expected_result = pd.merge(test, population, on = 'planning_area')
test['population'] = expected_result['population']
test['area_size'] = expected_result['area_size']

# %%
sns.boxplot(train['population'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='population'>

# %%
train.loc[train['population'] > 45000, 'population'] = 45000
sns.boxplot(train['population'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='population'>

# %%
fig, axes = plt.subplots(figsize=(18,8))
sns.boxplot(x ='population', y= 'planning_area', data=train)
axes.set_title('Population vs Planning Area')
plt.show()

# %% [markdown]
# ### Area_Size

# %%
sns.boxplot(train['area_size'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area_size'>

# %%
fig, axes = plt.subplots(figsize=(18,8))
sns.boxplot(x ='area_size', y= 'planning_area', data=train)
axes.set_title('Area_size vs Planning Area')
plt.show()

# %%
train.loc[train['area_size'] > 3.5, 'area_size'] = 3.5
sns.boxplot(train['area_size'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area_size'>

# %%
fig, axes = plt.subplots(figsize=(18,8))
sns.boxplot(x ='area_size', y= 'planning_area', data=train)
axes.set_title('Area_size vs Planning Area')
plt.show()

# %% [markdown]
# ### Property Type cleaning

# %%
#Change all to uppercase
train['property_type']=train['property_type'].str.upper()

#Change all to uppercase
test['property_type']=test['property_type'].str.upper()

# %%
property_to_keep = test['property_type'].unique()
train.property_type.isin(property_to_keep)

train[~train.property_type.isin(property_to_keep)]
# Out:
#        listing_id                                             title  \
# 635        432676  3 bed house for sale in the glencaird residences
# 1575       178157             5 bed house for sale in fuyong estate
# 19090      727605           2 bed house for sale in 265 outram road
#
#            address             property_name property_type             tenure  \
# 635    dalvey road  the glencaird residences     LAND ONLY           freehold
# 1575     jalan uji             fuyong estate     LAND ONLY  99-year leasehold
# 19090  outram road           265 outram road     SHOPHOUSE           freehold
#
#        built_year  num_beds  num_baths  size_sqft  ...        subzone  \
# 635        2000.0       3.0        3.0        107  ...        tanglin
# 1575          NaN       5.0        5.0       5726  ...  bukit panjang
# 19090      2019.0       2.0        2.0        657  ...         outram
#
#        planning_area        price  cc_distance mrt_distance  \
# 635          tanglin  101640000.0     7.065196     9.126171
# 1575   bukit panjang    1257900.0    12.424904    10.844287
# 19090         outram    1621100.0    10.324064     1.401878
#
#        primary_school_distance  secondary_school_distance  shop_distance  \
# 635                  10.128764                  12.080913      12.080913
# 1575                 14.961924                  11.324306      11.324306
# 19090                13.072322                  13.021354      13.021354
#
#       population area_size
# 635         2620    0.4364
# 1575       10250    1.4329
# 19090       6440    2.0385
#
# [3 rows x 28 columns]

# %%
categories_not_in_test = ['LAND ONLY', 'SHOPHOUSE']
train = train[train['property_type'].isin(categories_not_in_test) == False]

# %%
train['property_type'] = train['property_type'].replace(
    ['CLUSTER HOUSE', 'CONSERVATION HOUSE', 'LANDED', 'WALK-UP', 'TOWNHOUSE', 'GOOD CLASS BUNGALOW', 'CORNER TERRACE', 'SEMI-DETACHED HOUSE', 'BUNGALOW', 'TERRACED HOUSE'],
    'LANDED'
)

test['property_type'] = test['property_type'].replace(
    ['CLUSTER HOUSE', 'CONSERVATION HOUSE', 'LANDED', 'WALK-UP', 'TOWNHOUSE', 'GOOD CLASS BUNGALOW', 'CORNER TERRACE', 'SEMI-DETACHED HOUSE', 'BUNGALOW', 'TERRACED HOUSE'],
    'LANDED'
)
# Out:
# /var/folders/h9/l44j6mk55350xrm9bj2dqtfw0000gp/T/ipykernel_75487/2302593245.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['property_type'] = train['property_type'].replace(

# %%
train['property_type'] = train['property_type'].replace(
    ['HDB 3 ROOMS', 'HDB 4 ROOMS', 'HDB 5 ROOMS', 'HDB EXECUTIVE', 'HDB 2 ROOMS', 'APARTMENT'],
    'HDB'
)

test['property_type'] = test['property_type'].replace(
    ['HDB 3 ROOMS', 'HDB 4 ROOMS', 'HDB 5 ROOMS', 'HDB EXECUTIVE', 'HDB 2 ROOMS', 'APARTMENT'],
    'HDB'
)
# Out:
# /var/folders/h9/l44j6mk55350xrm9bj2dqtfw0000gp/T/ipykernel_75487/292634085.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['property_type'] = train['property_type'].replace(

# %%
train['property_type'] = train['property_type'].replace(
    ['EXECUTIVE CONDO'],
    'CONDO'
)

test['property_type'] = test['property_type'].replace(
    ['EXECUTIVE CONDO'],
    'CONDO'
)
# Out:
# /var/folders/h9/l44j6mk55350xrm9bj2dqtfw0000gp/T/ipykernel_75487/3536048392.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['property_type'] = train['property_type'].replace(

# %% [markdown]
# ### Tenure

# %%
train['tenure'] = train['tenure'].replace(
    [
    '99-year leasehold',
    '110-year leasehold',
    '103-year leasehold',
    '102-year leasehold',
    '100-year leasehold',
    ],
    '99-year leasehold'
)

train['tenure'] = train['tenure'].replace(
    [
    '946-year leasehold',
    '999-year leasehold',
    '956-year leasehold',
    '929-year leasehold',
    '947-year leasehold',
    '999-year leasehold'
    ],
    'freehold'
)



test['tenure'] = test['tenure'].replace(
    [
    '99-year leasehold',
    '110-year leasehold',
    '103-year leasehold',
    '102-year leasehold',
    '100-year leasehold',
    ],
    '99-year leasehold'
)

test['tenure'] = test['tenure'].replace(
    [
    '946-year leasehold',
    '999-year leasehold',
    '956-year leasehold',
    '929-year leasehold',
    '947-year leasehold',
    '999-year leasehold',
    ],
    'freehold'
)
# Out:
# /var/folders/h9/l44j6mk55350xrm9bj2dqtfw0000gp/T/ipykernel_75487/193539786.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['tenure'] = train['tenure'].replace(
# /var/folders/h9/l44j6mk55350xrm9bj2dqtfw0000gp/T/ipykernel_75487/193539786.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['tenure'] = train['tenure'].replace(

# %%
test['tenure'] = test['tenure'].fillna('99-year leasehold')

# %%
train['tenure'] = train['tenure'].fillna('99-year leasehold')
# Out:
# /var/folders/h9/l44j6mk55350xrm9bj2dqtfw0000gp/T/ipykernel_75487/3856521540.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['tenure'] = train['tenure'].fillna('99-year leasehold')

# %%
## Remove NA 
train = train.dropna(subset=['tenure'])

## Remove NA 
test['tenure'] = test['tenure'].fillna('99-year leasehold')

# %%
#for regression only

# from sklearn import preprocessing
# tenurepp = preprocessing.LabelEncoder()
# tenurepp.fit(train['tenure'])
# train['tenure']=tenurepp.transform(train['tenure'])

# test['tenure']=tenurepp.transform(test['tenure'])

# %% [markdown]
# ### Funishing

# %%
#Assume not specified and na as unfurnished 
train['furnishing'] = train['furnishing'].replace(
    [
    'na',
    'unspecified',
    ],
    'unfurnished'
)

#Assume not specified and na as unfurnished 
test['furnishing'] = test['furnishing'].replace(
    [
    'na',
    'unspecified',
    ],
    'unfurnished'
)

# %%
# #Assume not specified and na as unfurnished 
# train['furnishing'] = train['furnishing'].replace(
#     [
#     'fully',
#     ],
#     'partial'
# )

# #Assume not specified and na as unfurnished 
# test['furnishing'] = test['furnishing'].replace(
#     [
#     'fully',
#     ],
#     'partial'
# )

# %%
#for regression only

# from sklearn import preprocessing
# furnishing = preprocessing.LabelEncoder()
# furnishing.fit(train['furnishing'])
# train['furnishing']=furnishing.transform(train['furnishing'])

# test['furnishing']=furnishing.transform(test['furnishing'])

# %% [markdown]
# ### floor_level

# %%
# Too few data for floor level, we should just take out the column
train = train.drop(columns='floor_level')

# Too few data for floor level, we should just take out the column
test = test.drop(columns='floor_level')

# %% [markdown]
# ### total_num_units

# %%
mediantotalunit = train['total_num_units'].median()
train['total_num_units'].fillna(mediantotalunit, inplace=True)

mediantotalunit = test['total_num_units'].median()
test['total_num_units'].fillna(mediantotalunit, inplace=True)

# %%
sns.boxplot(train['total_num_units'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_num_units'>

# %%
train.loc[train['total_num_units'] > 900, 'total_num_units'] = 900
# Creating plot
sns.boxplot(train['total_num_units'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_num_units'>

# %%
test.loc[test['total_num_units'] > 900, 'total_num_units'] = 900

# %%
train.count()
# Out:
# listing_id                   20251
# title                        20251
# address                      20251
# property_name                20251
# property_type                20251
# tenure                       20251
# built_year                   19330
# num_beds                     20171
# num_baths                    19817
# size_sqft                    20251
# furnishing                   20251
# available_unit_types         18810
# total_num_units              20251
# property_details_url         20251
# lat                          20251
# lng                          20251
# elevation                    20251
# subzone                      20251
# planning_area                20251
# price                        20251
# cc_distance                  20251
# mrt_distance                 20251
# primary_school_distance      20251
# secondary_school_distance    20251
# shop_distance                20251
# population                   20251
# area_size                    20251
# dtype: int64

# %% [markdown]
# ### build year

# %%
train.count()
# Out:
# listing_id                   20251
# title                        20251
# address                      20251
# property_name                20251
# property_type                20251
# tenure                       20251
# built_year                   19330
# num_beds                     20171
# num_baths                    19817
# size_sqft                    20251
# furnishing                   20251
# available_unit_types         18810
# total_num_units              20251
# property_details_url         20251
# lat                          20251
# lng                          20251
# elevation                    20251
# subzone                      20251
# planning_area                20251
# price                        20251
# cc_distance                  20251
# mrt_distance                 20251
# primary_school_distance      20251
# secondary_school_distance    20251
# shop_distance                20251
# population                   20251
# area_size                    20251
# dtype: int64

# %%
train['built_year'].isnull().sum() / train['built_year'].sum()
# Out:
# 2.369472061557495e-05

# %%
train.loc[train['built_year'] < 1966, 'built_year'] = 1966
sns.boxplot(train['built_year'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='built_year'>

# %%
avgbuildyear = round(train['built_year'].median(),0)
train['built_year'] = train['built_year'].fillna(avgbuildyear)

avgbuildyear = round(test['built_year'].median(),0)
test['built_year'] = test['built_year'].fillna(avgbuildyear)

# %%
sns.boxplot(test['built_year'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='built_year'>

# %%
test.loc[test['built_year'] < 1966, 'built_year'] = 1966
sns.boxplot(test['built_year'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='built_year'>

# %% [markdown]
# ### num_baths

# %%
sns.boxplot(train['num_baths'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='num_baths'>

# %%
a = train[train['num_baths'].isna()]
a[a['num_beds'].isna()]
# Out:
#        listing_id                                              title  \
# 3713       765815            studio house for sale in dunearn estate
# 4691       478727            studio condo for sale in one pearl bank
# 4939       831032      hdb flat for sale in 539 bedok north street 3
# 5002       730482            hdb flat for sale in 205a punggol field
# 11500      120518  hdb flat for sale in 247 bukit batok east aven...
#
#                                                  address  \
# 3713                                       camborne road
# 4691                                        1 pearl bank
# 4939                      bedok / upper east coast (d16)
# 5002                  hougang / punggol / sengkang (d19)
# 11500  bukit batok / bukit panjang / choa chu kang (d23)
#
#                   property_name property_type             tenure  built_year  \
# 3713             dunearn estate        LANDED           freehold      1990.0
# 4691             one pearl bank         CONDO  99-year leasehold      2023.0
# 4939   539 bedok north street 3           HDB  99-year leasehold      1980.0
# 5002         205a punggol field           HDB  99-year leasehold      2004.0
# 11500               gombak view           HDB  99-year leasehold      1985.0
#
#        num_beds  num_baths  size_sqft  ...      subzone planning_area  \
# 3713        NaN        NaN       9594  ...       novena        novena
# 4691        NaN        NaN        431  ...       outram        outram
# 4939        NaN        NaN        731  ...        bedok         bedok
# 5002        NaN        NaN       1184  ...      punggol       punggol
# 11500       NaN        NaN        786  ...  bukit batok   bukit batok
#
#             price cc_distance  mrt_distance  primary_school_distance  \
# 3713   16275000.0    5.668353      5.872226                 6.905858
# 4691    1222200.0    5.825357      8.355056                11.798265
# 4939     367500.0   15.229001      7.025831                 8.583307
# 5002     669900.0   16.664632      6.751215                 7.404180
# 11500    409500.0    8.707527      4.914059                 6.279880
#
#        secondary_school_distance shop_distance population  area_size
# 3713                   11.134265     11.134265       2620     0.4364
# 4691                   15.372730     15.372730        890     2.2068
# 4939                   13.354867     13.354867      42240     1.3402
# 5002                    7.477411      7.477411      42240     1.3402
# 11500                  18.454836     18.454836      24760     1.0619
#
# [5 rows x 27 columns]

# %%
avgbath = train['num_baths'].median()
train['num_baths'] = train['num_baths'].fillna(avgbath)

avgbath = test['num_baths'].median()
test['num_baths'] = test['num_baths'].fillna(avgbath)

# %%
train.loc[train['num_baths'] > 4, 'num_baths'] = 4
sns.boxplot(train['num_baths'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='num_baths'>

# %%
test.loc[test['num_baths'] > 4, 'num_baths'] = 4
sns.boxplot(train['num_baths'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='num_baths'>

# %% [markdown]
# ### num_beds

# %%
avgbed = train['num_beds'].median()
train['num_beds'] = train['num_beds'].fillna(avgbath)

avgbed = test['num_beds'].median()
test['num_beds'] = test['num_beds'].fillna(avgbath)

# %%
fig, axes = plt.subplots(figsize=(18,8))
sns.boxplot(x ='property_type', y= 'num_beds', data=test)
axes.set_title('Property_type VS Number of Beds')
plt.show()

# %%
sns.boxplot(train['num_beds'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='num_beds'>

# %%
train.loc[train['num_beds'] > 7, 'num_beds'] = 7
sns.boxplot(train['num_beds'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='num_beds'>

# %% [markdown]
# ### num_avaliable_units

# %%
numavaunittypes = train.available_unit_types.str.count(',') + 1
train['available_unit_types'] = numavaunittypes

# %%
sns.boxplot(train['available_unit_types'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='available_unit_types'>

# %%
train.loc[train['available_unit_types'] > 9, 'available_unit_types'] = 9

# %%
sns.boxplot(train['available_unit_types'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='available_unit_types'>

# %%
avg_ava_units = train['available_unit_types'].median()
train['available_unit_types'] = train['available_unit_types'].fillna(avg_ava_units)

# %%
numavaunittypes = test.available_unit_types.str.count(',') +1
test['available_unit_types'] = numavaunittypes

# %%
avg_ava_units = test['available_unit_types'].median()
test['available_unit_types'] = test['available_unit_types'].fillna(avg_ava_units)

# %%
train.head()
# Out:
#    listing_id                                              title  \
# 0      122881          hdb flat for sale in 866 yishun street 81
# 1      259374  hdb flat for sale in 506b serangoon north aven...
# 2      665422                 4 bed condo for sale in meyerhouse
# 3      857699               3 bed condo for sale in leedon green
# 4      216061                 2 bed condo for sale in one bernam
#
#                               address         property_name property_type  \
# 0            sembawang / yishun (d27)  866 yishun street 81           HDB
# 1  hougang / punggol / sengkang (d19)  hdb-serangoon estate           HDB
# 2                      128 meyer road            meyerhouse         CONDO
# 3                   26 leedon heights          leedon green         CONDO
# 4                     1 bernam street            one bernam         CONDO
#
#               tenure  built_year  num_beds  num_baths  size_sqft  ...  \
# 0  99-year leasehold      1988.0       3.0        2.0       1115  ...
# 1  99-year leasehold      1992.0       4.0        2.0       1575  ...
# 2           freehold      2022.0       4.0        4.0       3070  ...
# 3           freehold      2023.0       3.0        2.0        958  ...
# 4  99-year leasehold      2026.0       2.0        1.0        732  ...
#
#          subzone  planning_area      price cc_distance  mrt_distance  \
# 0         yishun         yishun   514500.0    8.027727      1.689357
# 1      serangoon      serangoon   995400.0    2.400374      6.871207
# 2  marine parade  marine parade  8485000.0    6.389766     13.983476
# 3    bukit timah    bukit timah  2626000.0    8.802339     13.479646
# 4  downtown core  downtown core  1764000.0    9.160635     15.981982
#
#    primary_school_distance  secondary_school_distance shop_distance  \
# 0                 5.178683                   2.538065      2.538065
# 1                 8.310177                   6.710202      6.710202
# 2                 9.485153                  15.197137     15.197137
# 3                 3.290085                  12.950660     12.950660
# 4                13.818954                  17.977600     17.977600
#
#   population  area_size
# 0      10250     1.4329
# 1      18660     3.5000
# 2        890     2.2068
# 3      28000     1.5110
# 4       4370     2.2092
#
# [5 rows x 27 columns]

# %%
train.dtypes
# Out:
# listing_id                     int64
# title                         object
# address                       object
# property_name                 object
# property_type                 object
# tenure                        object
# built_year                   float64
# num_beds                     float64
# num_baths                    float64
# size_sqft                      int64
# furnishing                    object
# available_unit_types         float64
# total_num_units              float64
# property_details_url          object
# lat                          float64
# lng                          float64
# elevation                      int64
# subzone                       object
# planning_area                 object
# price                        float64
# cc_distance                  float64
# mrt_distance                 float64
# primary_school_distance      float64
# secondary_school_distance    float64
# shop_distance                float64
# population                     int64
# area_size                    float64
# dtype: object

# %% [markdown]
# ### price

# %% [markdown]
# Remove price which is 0

# %%
train = train[train['price'] != 0]

# %%
train['log_price'] = np.log1p(train['price'])

# %%
sns.boxplot(train['log_price'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='log_price'>

# %%
train = train[train['log_price']<20]
sns.boxplot(train['log_price'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='log_price'>

# %%
sns.boxplot(x=train['log_price'], y =train['property_type'])
# Out:
# <AxesSubplot:xlabel='log_price', ylabel='property_type'>

# %%
train = train[train['log_price'] < 17.1]
sns.boxplot(x=train['log_price'], y =train['property_type'])
# Out:
# <AxesSubplot:xlabel='log_price', ylabel='property_type'>

# %%
sns.boxplot(train['log_price'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='log_price'>

# %%
train = train[train['log_price'] <= 17]

# %%
sns.boxplot(train['price'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
train.count()
# Out:
# listing_id                   19994
# title                        19994
# address                      19994
# property_name                19994
# property_type                19994
# tenure                       19994
# built_year                   19994
# num_beds                     19994
# num_baths                    19994
# size_sqft                    19994
# furnishing                   19994
# available_unit_types         19994
# total_num_units              19994
# property_details_url         19994
# lat                          19994
# lng                          19994
# elevation                    19994
# subzone                      19994
# planning_area                19994
# price                        19994
# cc_distance                  19994
# mrt_distance                 19994
# primary_school_distance      19994
# secondary_school_distance    19994
# shop_distance                19994
# population                   19994
# area_size                    19994
# log_price                    19994
# dtype: int64

# %% [markdown]
# ### size_sqft

# %%
sns.boxplot(x = train['size_sqft'])
# Out:
# <AxesSubplot:xlabel='size_sqft'>

# %%
train['log_size_sqft'] = np.log1p(train['size_sqft'])
test['log_size_sqft'] = np.log1p(test['size_sqft'])

# %%
train = train.drop(columns='size_sqft')
test = test.drop(columns='size_sqft')

# %%
sns.boxplot(train['log_size_sqft'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='log_size_sqft'>

# %%
sns.boxplot(x = train['log_size_sqft'], y = train['property_type'])
# Out:
# <AxesSubplot:xlabel='log_size_sqft', ylabel='property_type'>

# %%
train = train[train['log_size_sqft'] <9.7]

# %%
sns.boxplot(x = train['log_size_sqft'], y = train['property_type'])
# Out:
# <AxesSubplot:xlabel='log_size_sqft', ylabel='property_type'>

# %%
train = train[train['log_size_sqft'] > 5.5]
sns.boxplot(x = train['log_size_sqft'], y = train['property_type'])
# Out:
# <AxesSubplot:xlabel='log_size_sqft', ylabel='property_type'>

# %%
sns.boxplot(train['log_size_sqft'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='log_size_sqft'>

# %% [markdown]
# ### subzone and planning_area

# %%
# adding regions
central = ['bishan', 'bukit merah', 'bukit timah', 'downtown core', 'geylang', 'kallang', 'marina east', 'marina south', 'marine parade', 'museum', 'newton',
           'novena', 'orchard', 'outram', 'queenstown', 'river valley', 'rochor', 'singapore river', 'southern islands', 'straits view', 'tanglin', 'toa payoh', 'geyland']

east = [ 'bedok', 'changi', 'changi bay', 'pasir ris', 'paya lebar', 'tampines']

north = ['central water catchment', 'lim chu kang', 'mandai', 'sembawang', 'simpang', 'sungei kadut', 'woodlands', 'yishun']

north_east = ['ang mo kio', 'hougang', 'north-eastern islands', 'punggol', 'seletar', 'sengkang', 'serangoon']

west = ['boon lay', 'bukit batok', 'bukit panjang', 'choa chu kang', 'clementi', 'jurong east', 'jurong west', 'pioneer', 'tengah', 'tuas', 'western islands', 'western water catchment']

# %%
train['region'] = train['subzone'].copy()

# %%
train['region'] = train['region'].replace(
    central,
    'central'
)

train['region'] = train['region'].replace(
    east,
    'east'
)

train['region'] = train['region'].replace(
    north,
    'north'
)

train['region'] = train['region'].replace(
    north_east,
    'north_east'
)

train['region'] = train['region'].replace(
    west,
    'west'
)

# %%
train.head()
# Out:
#    listing_id                                              title  \
# 0      122881          hdb flat for sale in 866 yishun street 81
# 1      259374  hdb flat for sale in 506b serangoon north aven...
# 2      665422                 4 bed condo for sale in meyerhouse
# 3      857699               3 bed condo for sale in leedon green
# 4      216061                 2 bed condo for sale in one bernam
#
#                               address         property_name property_type  \
# 0            sembawang / yishun (d27)  866 yishun street 81           HDB
# 1  hougang / punggol / sengkang (d19)  hdb-serangoon estate           HDB
# 2                      128 meyer road            meyerhouse         CONDO
# 3                   26 leedon heights          leedon green         CONDO
# 4                     1 bernam street            one bernam         CONDO
#
#               tenure  built_year  num_beds  num_baths   furnishing  ...  \
# 0  99-year leasehold      1988.0       3.0        2.0  unfurnished  ...
# 1  99-year leasehold      1992.0       4.0        2.0  unfurnished  ...
# 2           freehold      2022.0       4.0        4.0      partial  ...
# 3           freehold      2023.0       3.0        2.0      partial  ...
# 4  99-year leasehold      2026.0       2.0        1.0  unfurnished  ...
#
#    cc_distance  mrt_distance primary_school_distance  \
# 0     8.027727      1.689357                5.178683
# 1     2.400374      6.871207                8.310177
# 2     6.389766     13.983476                9.485153
# 3     8.802339     13.479646                3.290085
# 4     9.160635     15.981982               13.818954
#
#    secondary_school_distance  shop_distance  population area_size  log_price  \
# 0                   2.538065       2.538065       10250    1.4329  13.150953
# 1                   6.710202       6.710202       18660    3.5000  13.810901
# 2                  15.197137      15.197137         890    2.2068  15.953811
# 3                  12.950660      12.950660       28000    1.5110  14.780973
# 4                  17.977600      17.977600        4370    2.2092  14.383095
#
#    log_size_sqft      region
# 0       7.017506       north
# 1       7.362645  north_east
# 2       8.029759     central
# 3       6.865891     central
# 4       6.597146     central
#
# [5 rows x 29 columns]

# %%
train['region']
# Out:
# 0             north
# 1        north_east
# 2           central
# 3           central
# 4           central
#             ...
# 20249    north_east
# 20250       central
# 20251       central
# 20252         north
# 20253       central
# Name: region, Length: 19967, dtype: object

# %%
sns.countplot(x='region', data=train)
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
test['region'] = test['subzone'].copy()
test['region'].unique()
# Out:
# array(['serangoon', 'pasir ris', 'museum', 'choa chu kang', 'toa payoh',
#        'geylang', 'clementi', 'yishun', 'hougang', 'sengkang',
#        'bukit batok', 'bukit panjang', 'woodlands', 'ang mo kio',
#        'downtown core', 'queenstown', 'kallang', 'bukit timah', 'bedok',
#        'river valley', 'novena', 'seletar', 'bishan', 'outram', 'tanglin',
#        'jurong west', 'marine parade', 'punggol', 'sembawang',
#        'singapore river', 'bukit merah', 'southern islands', 'changi',
#        'newton', 'tampines', 'orchard', 'jurong east', 'tengah', 'rochor',
#        'central water catchment', 'geyland', 'lim chu kang', 'mandai',
#        'boon lay'], dtype=object)

# %%
test['region'] = test['region'].replace(
    central,
    'central'
)

test['region'] = test['region'].replace(
    east,
    'east'
)

test['region'] = test['region'].replace(
    north,
    'north'
)

test['region'] = test['region'].replace(
    north_east,
    'north_east'
)

test['region'] = test['region'].replace(
    west,
    'west'
)

test['region'].unique()
# Out:
# array(['north_east', 'east', 'central', 'west', 'north'], dtype=object)

# %%
test.head()
# Out:
#    listing_id                                             title  \
# 0      777912               1 bed condo for sale in the gazania
# 1      936612           3 bed condo for sale in vue 8 residence
# 2      995264                      1 bed condo for sale in icon
# 3      477435  hdb flat for sale in 812b choa chu kang avenue 7
# 4      222529          hdb flat for sale in 204 toa payoh north
#
#                                              address      property_name  \
# 0                                   17 how sun drive        the gazania
# 1                               95 pasir ris heights    vue 8 residence
# 2                                   10 gopeng street               icon
# 3  bukit batok / bukit panjang / choa chu kang (d23)  keat hong colours
# 4                        balestier / toa payoh (d12)   toa payoh spring
#
#   property_type             tenure  built_year  num_beds  num_baths  \
# 0         CONDO           freehold      2022.0       1.0        1.0
# 1         CONDO  99-year leasehold      2017.0       3.0        3.0
# 2         CONDO  99-year leasehold      2007.0       1.0        1.0
# 3           HDB  99-year leasehold      2017.0       3.0        2.0
# 4           HDB  99-year leasehold      1973.0       3.0        2.0
#
#     furnishing  ...  planning_area  cc_distance mrt_distance  \
# 0  unfurnished  ...      serangoon     1.046868     0.960436
# 1  unfurnished  ...      pasir ris     8.581574     9.346690
# 2        fully  ...         museum     6.755363     6.710905
# 3  unfurnished  ...  choa chu kang    14.229296    14.293216
# 4  unfurnished  ...      toa payoh     2.802424     2.077951
#
#    primary_school_distance  secondary_school_distance  shop_distance  \
# 0                13.993735                   1.853769       1.853769
# 1                13.709624                   8.403509       8.403509
# 2                 8.965840                   6.503082       6.503082
# 3                12.559347                  13.963584      13.963584
# 4                 6.903112                   3.079569       3.079569
#
#   population area_size  log_size_sqft      region
# 0       8490    1.1801       6.139885  north_east
# 1      14700    2.3307       6.941190        east
# 2      24760    1.0619       6.347389     central
# 3      36080    3.0232       7.104144        west
# 4      15940    0.6847       6.842683     central
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Types

# %%
train.dtypes
# Out:
# listing_id                     int64
# title                         object
# address                       object
# property_name                 object
# property_type                 object
# tenure                        object
# built_year                   float64
# num_beds                     float64
# num_baths                    float64
# furnishing                    object
# available_unit_types         float64
# total_num_units              float64
# property_details_url          object
# lat                          float64
# lng                          float64
# elevation                      int64
# subzone                       object
# planning_area                 object
# price                        float64
# cc_distance                  float64
# mrt_distance                 float64
# primary_school_distance      float64
# secondary_school_distance    float64
# shop_distance                float64
# population                     int64
# area_size                    float64
# log_price                    float64
# log_size_sqft                float64
# region                        object
# dtype: object

# %% [markdown]
# ### Remove Redundant features

# %%
train.dtypes
# Out:
# listing_id                     int64
# title                         object
# address                       object
# property_name                 object
# property_type                 object
# tenure                        object
# built_year                   float64
# num_beds                     float64
# num_baths                    float64
# furnishing                    object
# available_unit_types         float64
# total_num_units              float64
# property_details_url          object
# lat                          float64
# lng                          float64
# elevation                      int64
# subzone                       object
# planning_area                 object
# price                        float64
# cc_distance                  float64
# mrt_distance                 float64
# primary_school_distance      float64
# secondary_school_distance    float64
# shop_distance                float64
# population                     int64
# area_size                    float64
# log_price                    float64
# log_size_sqft                float64
# region                        object
# dtype: object

# %%
test.count()
# Out:
# listing_id                   6966
# title                        6966
# address                      6964
# property_name                6966
# property_type                6966
# tenure                       6966
# built_year                   6966
# num_beds                     6966
# num_baths                    6966
# furnishing                   6966
# available_unit_types         6966
# total_num_units              6966
# property_details_url         6966
# lat                          6966
# lng                          6966
# elevation                    6966
# subzone                      6966
# planning_area                6966
# cc_distance                  6966
# mrt_distance                 6966
# primary_school_distance      6966
# secondary_school_distance    6966
# shop_distance                6966
# population                   6966
# area_size                    6966
# log_size_sqft                6966
# region                       6966
# dtype: int64

# %% [markdown]
# ### Distance Correlation Analysis

# %%
# distance_list = ['cc_distance', 'mrt_distance', 'primary_school_distance', 'secondary_school_distance', 'shop_distance']
# print('spearman:')
# for distance_type in distance_list:
#     print(train[distance_type].corr(y_train, method='spearman'))
# print('kendall:')
# for distance_type in distance_list:
#     print(train[distance_type].corr(y_train, method='kendall'))

# %% [markdown]
# The distance ranked by correlation is like this:
# 1. distance to MRT station
# 2. distance to Commercial Centre
# 3. distance to Shopping mall
# 4. distance to Secondary school
# 5. distance to Primary school
# Result shows that the influence of distance to Primary school is very little and can almost be ignored. On the contrary, distance to MRT station affect the price obviously.

# %% [markdown]
# ##### Prominent primary schools
# - Add a new feature on [popular primary schools](https://www.moe.gov.sg/primary/p1-registration/distance) priority is given to people living < 2 km near these schools.
# - Added [top 28 oversubscribed schools](https://www.salary.sg/2022/best-primary-schools-2022-by-popularity/)

# %%
# Top 28 oversubscribed schools
pslist = """
Methodist Girls’ School (Primary) – 20/79 (2.55)
Catholic High School (Primary Section) – 20/43 (1.74)
Tao Nan School – 23/61 (1.74)
Pei Hwa Presbyterian Primary School – 20/37 (1.64)
Holy Innocents’ Primary School – 21/50 (1.64)
Nan Hua Primary School – 20/38 (1.61)
CHIJ St. Nicholas Girls’ School (Primary Section) – 20/46 (1.59)
Admiralty Primary School – 22/49 (1.52)
St. Hilda’s Primary School – 20/40 (1.49)
Ai Tong School – 20/48 (1.45)
Anglo-Chinese School (Junior) – 27/57 (1.44)
Chongfu School – 25/51 (1.35)
St. Joseph’s Institution Junior – 38/84 (1.35)
Anglo-Chinese School (Primary) – 28/55 (1.34)
Singapore Chinese Girls’ Primary School – 20/34 (1.30)
Nanyang Primary School – 20/37 (1.30)
South View Primary School – 20/30 (1.29)
Pei Chun Public School – 20/27 (1.27)
Kong Hwa School – 32/65 (1.20)
Rosyth School – 20/24 (1.18)
Maris Stella High School (Primary Section) – 27/45 (1.18)
Nan Chiau Primary School – 41/79 (1.13)
Fairfield Methodist School (Primary) – 20/33 (1.13)
CHIJ Primary (Toa Payoh) – 27/40 (1.12)
Henry Park Primary School – 21/29 (1.10)
Kuo Chuan Presbyterian Primary School – 31/54 (1.10)
Red Swastika School – 20/26 (1.08)
Rulang Primary School – 20/34 (1.07)
"""

# %%
psl = []
for school in pslist.split('\n'):
    if school != '':
        num_idx = [elem for elem in school if elem.isnumeric()] # Find index of numbers
        num_idx = school.index(num_idx[0])-3 # The first number is always after the '-'
        school = school[:num_idx]
        # If there is '(Primary)' inside the term
        if '(Primary' in school:
            school = school[:school.index('(Primary')-1]
        # # Get the school main name
        # school = school.split(' ')[:2]
        # Replace special character ’ with '
        school = school.replace("’", "'" )
        # psl.append(' '.join(school))
        psl.append(school)
print(psl)
# Out:
# ["Methodist Girls' School", 'Catholic High School', 'Tao Nan School', 'Pei Hwa Presbyterian Primary School', "Holy Innocents' Primary School", 'Nan Hua Primary School', "CHIJ St. Nicholas Girls' School", 'Admiralty Primary School', "St. Hilda's Primary School", 'Ai Tong School', 'Anglo-Chinese School (Junior)', 'Chongfu School', "St. Joseph's Institution Junior", 'Anglo-Chinese School', "Singapore Chinese Girls' Primary School", 'Nanyang Primary School', 'South View Primary School', 'Pei Chun Public School', 'Kong Hwa School', 'Rosyth School', 'Maris Stella High School', 'Nan Chiau Primary School', 'Fairfield Methodist School', 'CHIJ Primary (Toa Payoh)', 'Henry Park Primary School', 'Kuo Chuan Presbyterian Primary School', 'Red Swastika School', 'Rulang Primary School']

# %%
target_ps = set()
for name in primaryschooldistance.name.values:
    for target in psl:
        if target in name:
            target_ps.add(name)
target_ps
# Out:
# {'Admiralty Primary School',
#  'Ai Tong School',
#  'Anglo-Chinese School (Primary)',
#  'CHIJ Primary (Toa Payoh)',
#  "CHIJ St. Nicholas Girls' School",
#  'Catholic High School (Primary)',
#  'Chongfu School',
#  'Fairfield Methodist School (Primary)',
#  'Henry Park Primary School',
#  "Holy Innocents' Primary School",
#  'Kong Hwa School',
#  'Kuo Chuan Presbyterian Primary School',
#  'Maris Stella High School',
#  "Methodist Girls' School (Primary)",
#  'Nan Chiau Primary School',
#  'Nanyang Primary School',
#  "Paya Lebar Methodist Girls' School (Primary)",
#  'Pei Chun Public School',
#  'Pei Hwa Presbyterian Primary School',
#  'Red Swastika School',
#  'Rosyth School',
#  'Rulang Primary School',
#  'South View Primary School',
#  "St. Hilda's Primary School",
#  "St. Joseph's Institution Junior",
#  'Tao Nan School'}

# %% [markdown]
# Some schools have duplicate (Anglo-Chinese and Anglo-Chinese (Junior)) but is actually the same school located in the same location

# %%
target_ps = primaryschooldistance[primaryschooldistance.name.isin(list(target_ps))]
target_ps.sort_values(by=['subzone'])
# Out:
#                                              name       lat         lng  \
# 80                                Kong Hwa School  1.311261  103.888199
# 112           Pei Hwa Presbyterian Primary School  1.338099  103.776219
# 96                       Nan Chiau Primary School  1.392027  103.891042
# 127                           Red Swastika School  1.333420  103.934220
# 88                       Maris Stella High School  1.341431  103.877655
# 82          Kuo Chuan Presbyterian Primary School  1.349224  103.855026
# 2                                  Ai Tong School  1.375016  103.857415
# 65                 Holy Innocents' Primary School  1.375016  103.857415
# 49           Fairfield Methodist School (Primary)  1.300820  103.785649
# 97                         Nanyang Primary School  1.320832  103.808217
# 131                         Rulang Primary School  1.346609  103.718737
# 31                CHIJ St. Nicholas Girls' School  1.374226  103.834154
# 6                  Anglo-Chinese School (Primary)  1.318752  103.835077
# 148                                Tao Nan School  1.305067  103.911423
# 143               St. Joseph's Institution Junior  1.317640  103.845544
# 32                                 Chongfu School  1.438728  103.839290
# 111                        Pei Chun Public School  1.337312  103.855825
# 130                                 Rosyth School  1.373198  103.874697
# 110  Paya Lebar Methodist Girls' School (Primary)  1.349932  103.884924
# 94              Methodist Girls' School (Primary)  1.349932  103.884924
# 142                    St. Hilda's Primary School  1.349877  103.936094
# 137                     South View Primary School  1.382366  103.755999
# 30                       CHIJ Primary (Toa Payoh)  1.333127  103.842403
# 66                      Henry Park Primary School  1.317057  103.784216
# 22                 Catholic High School (Primary)  1.297219  103.851839
# 0                        Admiralty Primary School  1.442941  103.800345
#
#                subzone planning_area
# 80            aljunied     serangoon
# 112         anak bukit     serangoon
# 96          anchorvale     serangoon
# 127        bedok north     serangoon
# 88            bidadari     serangoon
# 82         bishan east     serangoon
# 2            cheng san     serangoon
# 65           cheng san     serangoon
# 49               dover     serangoon
# 97        farrer court     serangoon
# 131           hong kah     serangoon
# 31         kebun bahru     serangoon
# 6              malcolm     serangoon
# 148      marine parade     serangoon
# 143           moulmein     serangoon
# 32           northland     serangoon
# 111           pei chun     serangoon
# 130    serangoon north     serangoon
# 110           tai seng     serangoon
# 94            tai seng     serangoon
# 142      tampines west     serangoon
# 137          teck whye     serangoon
# 30   toa payoh central     serangoon
# 66          ulu pandan     serangoon
# 22            victoria     serangoon
# 0       woodlands east     serangoon

# %%
target_ps.lat.values
# Out:
# array([1.4429414 , 1.3750164 , 1.31875235, 1.29721925, 1.3331269 ,
#        1.37422574, 1.4387276 , 1.30081995, 1.3750164 , 1.3170569 ,
#        1.31126062, 1.3492238 , 1.341431  , 1.34993195, 1.39202675,
#        1.32083185, 1.34993195, 1.33731177, 1.3380993 , 1.33341967,
#        1.37319819, 1.34660905, 1.38236605, 1.34987736, 1.31764038,
#        1.30506679])

# %%
target_loc = {'lat':target_ps.lat.values, 'lng':target_ps.lng.values}
target_loc
# Out:
# {'lat': array([1.4429414 , 1.3750164 , 1.31875235, 1.29721925, 1.3331269 ,
#         1.37422574, 1.4387276 , 1.30081995, 1.3750164 , 1.3170569 ,
#         1.31126062, 1.3492238 , 1.341431  , 1.34993195, 1.39202675,
#         1.32083185, 1.34993195, 1.33731177, 1.3380993 , 1.33341967,
#         1.37319819, 1.34660905, 1.38236605, 1.34987736, 1.31764038,
#         1.30506679]),
#  'lng': array([103.80034507, 103.85741485, 103.83507692, 103.85183918,
#         103.842403  , 103.8341542 , 103.83929013, 103.78564896,
#         103.85741485, 103.78421633, 103.88819876, 103.85502581,
#         103.87765467, 103.88492376, 103.89104245, 103.80821659,
#         103.88492376, 103.85582516, 103.77621882, 103.93422016,
#         103.87469674, 103.718737  , 103.75599912, 103.93609377,
#         103.84554447, 103.91142327])}

# %%
len(target_loc)
# Out:
# 2

# %%
expected_result = pd.merge(train, target_ps, on = 'subzone')


def near_ps(t_lat, t_lng):
    # target_loc of [lat, lng]
    min_dist = np.inf
    for i in range(len(target_loc['lat'])):
        temp_d = haversine_np(t_lng, t_lat, target_loc['lng'][i], target_loc['lat'][i])
        if min_dist > temp_d:
            min_dist = temp_d
    return 1 if min_dist <= 2 else 0

train['near_top_ps'] = train.apply(lambda row : near_ps(row['lat'], row['lng']), axis = 1)

# %%
train['near_top_ps'].value_counts()
# Out:
# 1    14641
# 0     5326
# Name: near_top_ps, dtype: int64

# %%
test['near_top_ps'] = test.apply(lambda row : near_ps(row['lat'], row['lng']), axis = 1)

# %% [markdown]
# ### On Price

# %%
# Set up the matplotlib figure
plt.figure(figsize=(12,5))
#f, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)
plt.subplot(121)
sns.distplot(train['price'],kde=False)
plt.xlabel('Sale price')
plt.axis([100000,5000000,0,5000])
plt.subplot(122)
sns.distplot(np.log1p(train['price']),kde=False)
plt.xlabel('Log (sale price)')
# plt.axis([10,14,0,180])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Log (sale price)')

# %% [markdown]
# ### Overall correlation

# %%
corr = train.select_dtypes(include = ['float64', 'int64']).iloc[:,1:].corr()
#fig = plt.figure()
sns.set(font_scale=1)  
sns.heatmap(corr, vmax=1, square=True)
# Out:
# <AxesSubplot:>

# %%
corr_list = corr['log_price'].sort_values(axis=0,ascending=False).iloc[1:] # removes price
corr_list = corr_list[1:]

# %%
corr_list
# Out:
# log_size_sqft                0.697479
# num_baths                    0.676896
# num_beds                     0.557271
# built_year                   0.399874
# available_unit_types         0.250777
# near_top_ps                  0.033402
# lng                          0.012338
# area_size                    0.006972
# population                   0.005391
# lat                          0.002472
# primary_school_distance     -0.003889
# secondary_school_distance   -0.055665
# shop_distance               -0.062233
# total_num_units             -0.073563
# cc_distance                 -0.111482
# mrt_distance                -0.244142
# elevation                         NaN
# Name: log_price, dtype: float64

# %% [markdown]
# We want to get the biggest absolute value, which shows positively or negatively correlation, and try not to get variables that are close to 0.

# %%
corr_list = corr_list.abs().sort_values(axis=0,ascending=False).iloc[1:]

# %%
corr_list
# Out:
# num_baths                    0.676896
# num_beds                     0.557271
# built_year                   0.399874
# available_unit_types         0.250777
# mrt_distance                 0.244142
# cc_distance                  0.111482
# total_num_units              0.073563
# shop_distance                0.062233
# secondary_school_distance    0.055665
# near_top_ps                  0.033402
# lng                          0.012338
# area_size                    0.006972
# population                   0.005391
# primary_school_distance      0.003889
# lat                          0.002472
# elevation                         NaN
# Name: log_price, dtype: float64

# %% [markdown]
# Chart the price increase with each of the features, blue line shows the log_price, which displays *linearity* for some features, able to see linear patterns.

# %%
plt.figure(figsize=(18,8))
for i in range(6):
    ii = '23'+str(i+1)
    plt.subplot(int(ii))
    feature = corr_list.index.values[i]
    plt.scatter(train[feature], train['log_price'], facecolors='none',edgecolors='k',s = 75)
    sns.regplot(x = feature, y = 'log_price', data = train,scatter=False, color = 'Blue')
    ax=plt.gca() 
    ax.set_ylim([0,20])

# %% [markdown]
# See the price distribution of each subzone in Singapore, sort by median to see the price distribution, color coded by region (NSEWC). Can see that a few areas are consistently high (newton, orchard, river valley), most are central areas as seen by the hue color. A few are outliers (mandai which is a land).

# %%
# ps_df['region'].value_counts()

# %%
ps_df = train.__deepcopy__()

plt.figure(figsize = (30, 12))
grouped = ps_df.groupby(["subzone"])
order = grouped.median()["log_price"].sort_values().index
sns.boxplot(x="subzone", y="log_price", hue="region", data=ps_df, order=order)#, palette=ps_df.region.unique())
xt = plt.xticks(rotation=45)

# %%
# Violin plots for price distribution of each flat model

fig = plt.figure(figsize=(12,7))
p=sns.violinplot(x='property_type', y='price', data=train, width=1,
                order=train.groupby('property_type')['price'].median().sort_values().reset_index()['property_type'].tolist())
p.set_xticklabels(p.get_xticklabels(), rotation=30, ha='right'), p.set_xlabel('property type', size=15)
ylabels = ['{:,.0f}'.format(x) + 'K' for x in p.get_yticks()/1000]
p.set_yticklabels(ylabels)
p.set_ylabel('Resale Price SGD ($)', size=15)
plt.show()
# Out:
# /var/folders/h9/l44j6mk55350xrm9bj2dqtfw0000gp/T/ipykernel_75487/522973809.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   p.set_yticklabels(ylabels)

# %% [markdown]
# # Mining & Data Processing - Housing Apartment Price Prediction
# Involves a few steps to clean the noisy data and then prepare it for modeling.
# 1. Data Processing
# - Feature Selection - Remove unnecessary features
# - Outliers - Detect & Remove Outliers
# - Cleaning - Fill up Null and Missing Data
#
# 2. Prepare pipeline and set up categorical and numerical columns
#
# 3. Prediction is using log1p price instead of the actual price, when doing prediction, we will square the number back.

# %%
train['property_type'].unique()
# Out:
# array(['HDB', 'CONDO', 'LANDED'], dtype=object)

# %%
df_train = train[train["property_type"] != 'LANDED']
test = test[test["property_type"] != 'LANDED']

# %%
df_train['property_type'].unique()
# Out:
# array(['HDB', 'CONDO'], dtype=object)

# %% [markdown]
# ## Data Processing

# %% [markdown]
# ### Feature Selection
# Not all features are important, some features do not pass the common sense test ('lat', 'lng') or is duplicates('subzone', 'planning_area'). Even if the feature has no correlation, models will be smart enough to select the important ones
# - Remove also area-size which is actually the area of the planning area but do not have any relationship with any housing price
# - Remove 'listing_id', 'property_details_url','property_name','address','title', which do not have a correlation with price and contains too many unique values

# %%
df_train.dtypes
# Out:
# listing_id                     int64
# title                         object
# address                       object
# property_name                 object
# property_type                 object
# tenure                        object
# built_year                   float64
# num_beds                     float64
# num_baths                    float64
# furnishing                    object
# available_unit_types         float64
# total_num_units              float64
# property_details_url          object
# lat                          float64
# lng                          float64
# elevation                      int64
# subzone                       object
# planning_area                 object
# price                        float64
# cc_distance                  float64
# mrt_distance                 float64
# primary_school_distance      float64
# secondary_school_distance    float64
# shop_distance                float64
# population                     int64
# area_size                    float64
# log_price                    float64
# log_size_sqft                float64
# region                        object
# near_top_ps                    int64
# dtype: object

# %%
df_train.head()
# Out:
#    listing_id                                              title  \
# 0      122881          hdb flat for sale in 866 yishun street 81
# 1      259374  hdb flat for sale in 506b serangoon north aven...
# 2      665422                 4 bed condo for sale in meyerhouse
# 3      857699               3 bed condo for sale in leedon green
# 4      216061                 2 bed condo for sale in one bernam
#
#                               address         property_name property_type  \
# 0            sembawang / yishun (d27)  866 yishun street 81           HDB
# 1  hougang / punggol / sengkang (d19)  hdb-serangoon estate           HDB
# 2                      128 meyer road            meyerhouse         CONDO
# 3                   26 leedon heights          leedon green         CONDO
# 4                     1 bernam street            one bernam         CONDO
#
#               tenure  built_year  num_beds  num_baths   furnishing  ...  \
# 0  99-year leasehold      1988.0       3.0        2.0  unfurnished  ...
# 1  99-year leasehold      1992.0       4.0        2.0  unfurnished  ...
# 2           freehold      2022.0       4.0        4.0      partial  ...
# 3           freehold      2023.0       3.0        2.0      partial  ...
# 4  99-year leasehold      2026.0       2.0        1.0  unfurnished  ...
#
#    mrt_distance  primary_school_distance secondary_school_distance  \
# 0      1.689357                 5.178683                  2.538065
# 1      6.871207                 8.310177                  6.710202
# 2     13.983476                 9.485153                 15.197137
# 3     13.479646                 3.290085                 12.950660
# 4     15.981982                13.818954                 17.977600
#
#    shop_distance  population  area_size  log_price log_size_sqft      region  \
# 0       2.538065       10250     1.4329  13.150953      7.017506       north
# 1       6.710202       18660     3.5000  13.810901      7.362645  north_east
# 2      15.197137         890     2.2068  15.953811      8.029759     central
# 3      12.950660       28000     1.5110  14.780973      6.865891     central
# 4      17.977600        4370     2.2092  14.383095      6.597146     central
#
#    near_top_ps
# 0            0
# 1            1
# 2            1
# 3            1
# 4            0
#
# [5 rows x 30 columns]

# %% [markdown]
# For Numerical Columns

# %%
len(df_train.columns) - len(test.columns)
# Out:
# 2

# %%
set(df_train.columns) - set(test.columns)
# Out:
# {'log_price', 'price'}

# %%
# Drop irrelevant features
df_train = df_train.drop(columns=['listing_id', 'property_details_url','property_name','address','title'])
test = test.drop(columns=['listing_id', 'property_details_url','property_name','address','title'])

# Location-related features. Drop planning area related data, it is too broad to have a big impact
df_train = df_train.drop(columns=['lat','lng','planning_area', 'area_size'])
test = test.drop(columns=['lat','lng','planning_area', 'area_size'])

# # Final numerical columns
x_train = df_train.drop(columns=['price'])
y_train = x_train.pop('log_price')

# %%
x_train.columns
# Out:
# Index(['property_type', 'tenure', 'built_year', 'num_beds', 'num_baths',
#        'furnishing', 'available_unit_types', 'total_num_units', 'elevation',
#        'subzone', 'cc_distance', 'mrt_distance', 'primary_school_distance',
#        'secondary_school_distance', 'shop_distance', 'population',
#        'log_size_sqft', 'region', 'near_top_ps'],
#       dtype='object')

# %% [markdown]
# For categorical columns

# %%
[x_train.dtypes=='O']
# Out:
# [property_type                 True
#  tenure                        True
#  built_year                   False
#  num_beds                     False
#  num_baths                    False
#  furnishing                    True
#  available_unit_types         False
#  total_num_units              False
#  elevation                    False
#  subzone                       True
#  cc_distance                  False
#  mrt_distance                 False
#  primary_school_distance      False
#  secondary_school_distance    False
#  shop_distance                False
#  population                   False
#  log_size_sqft                False
#  region                        True
#  near_top_ps                  False
#  dtype: bool]

# %%
x_train.furnishing.value_counts()
# Out:
# unfurnished    14132
# partial         2738
# fully            500
# Name: furnishing, dtype: int64

# %%
x_train.columns
# Out:
# Index(['property_type', 'tenure', 'built_year', 'num_beds', 'num_baths',
#        'furnishing', 'available_unit_types', 'total_num_units', 'elevation',
#        'subzone', 'cc_distance', 'mrt_distance', 'primary_school_distance',
#        'secondary_school_distance', 'shop_distance', 'population',
#        'log_size_sqft', 'region', 'near_top_ps'],
#       dtype='object')

# %%
# Custom OHE for furnishing
furnishing_list = ['unfurnished', 'partial', 'fully']
furnishing_processor = OrdinalEncoder(categories=[furnishing_list])

furnishing_ct = ColumnTransformer(
    [
        ('furnish_label', furnishing_processor, ['furnishing'])
    ], remainder='drop'
)

# %% [markdown]
# ## Pipeline

# %%
# OHE for the other categorical variables
cat_columns = list(x_train.select_dtypes('object').columns)
cat_columns.remove('furnishing')
col = list(x_train.columns)

other_cat_processor = OneHotEncoder(handle_unknown="ignore")

final_cat_ct = ColumnTransformer(
    [
        ('OHE', other_cat_processor, cat_columns)
    ], remainder='drop'
)

# %%
num_columns = list(x_train.select_dtypes(exclude=['object']).columns)
num_columns.remove('near_top_ps')

final_furnishing_preprocessor = Pipeline([
    ("furnishing_process", furnishing_ct),
])

final_cat_preprocessor = Pipeline([
    ("othercat_process", final_cat_ct),
])

all_ct_pipeline = ColumnTransformer([
    ("furnishing", final_furnishing_preprocessor, ['furnishing']),
    ("cat", final_cat_preprocessor, cat_columns),
    ("RobustScaler", RobustScaler(), num_columns), # RobustScaler all 
])

# %%
x_train_scaled = all_ct_pipeline.fit_transform(x_train)

# %%
kfolds = RepeatedStratifiedKFold(n_splits=10, random_state=42)

def mean_squared_error_(ground_truth, predictions):
    return mean_squared_error(ground_truth, predictions) ** 0.5
RMSE = make_scorer(mean_squared_error_, greater_is_better=False) 
def find_single_best_model(rgr, param_grid, Xtrain,ytrain):
    print(param_grid)
    X_train = Xtrain
    y_train = ytrain
    
    param_grid = {}#'n_estimators': [500], 'max_features': [10,15,20]}
    model = GridSearchCV(estimator=rgr, param_grid=param_grid, n_jobs=-1, cv=10, scoring=RMSE)
    model.fit(X_train, y_train)
    print('Best Params:')
    print(model.best_params_)
    print('Best CV Score(RMSE):')
    print(-model.best_score_)
    return model.estimator

# %%
# Check the final rows and columns
x_train_scaled.shape
# Out:
# (17370, 65)

# %% [markdown]
# ## Modelling

# %%
# Defining error functions
# Based on Prof's requirements, we are using R-square and RMSE 



def rsq_pred(y, y_pred):
    return r2_score(y, y_pred)

def rmse_pred(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

def cv_rmse(clf, x, y):
    rmse = np.sqrt(-cross_val_score(clf, x, y, scoring="neg_mean_squared_error", cv=5, n_jobs=-1))
    return (rmse)

def get_PR_AUC(clf, x, y):
    avg_precision = cross_val_score(clf, x, y, scoring="neg_mean_squared_error", cv=5, n_jobs=-1).mean()
    return (avg_precision)

# %% [markdown]
# ### Level 0 Estimators Training

# %%
alphas_alt = [5,10,15,20]
alphas2 = [5e-05, 0.0001, 0.001, 0.01]
e_alphas= [0.0001, 0.001, 0.01]
e_l1ratio = [0.5,0.8,1.0]
svr = {'C':[5,10,20], 'epsilon':[0.001, 0.01, 0.1], 'gamma':[0.0001, 0.001, 0.01]}

# %%
# Built in CV models
ridge = RidgeCV(alphas=alphas_alt, cv=kfolds)
lasso = LassoCV(max_iter=1e7, alphas=alphas2, random_state=42, cv=kfolds)
elasticnet = ElasticNetCV(max_iter=1e7, alphas=e_alphas, cv=kfolds, l1_ratio=e_l1ratio)

# %%
# Param
alphas_alt = {'alpha':[5,10,15,20]}
print("Ridge")
model_ridge = GridSearchCV(estimator=Ridge(), param_grid=alphas_alt, n_jobs=-1, cv=10, scoring=RMSE)
model_ridge.fit(x_train_scaled, y_train)
print('Best Params:')
print(model_ridge.best_params_)
print('Best CV Score(RMSE):')
print(-model_ridge.best_score_)
# Out:
# Ridge
# Best Params:
# {'alpha': 5}
# Best CV Score(RMSE):
# 0.19094206104652497

# %%
# Param
alphas2 = {'alpha':[5e-05, 0.0001, 0.001, 0.01]}
print("Lasso")
model_lasso = GridSearchCV(estimator=Lasso(), param_grid=alphas2, n_jobs=-1, cv=10, scoring=RMSE)
model_lasso.fit(x_train_scaled, y_train)
print('Best Params:')
print(model_lasso.best_params_)
print('Best CV Score(RMSE):')
print(-model_lasso.best_score_)
# Out:
# Lasso
# Best Params:
# {'alpha': 5e-05}
# Best CV Score(RMSE):
# 0.19078170841568592

# %%
e_net = {'alpha':[0.0001, 0.001, 0.01], 'l1_ratio': [0.5,0.8,1.0]}
print("ElasticNet")
model_enet = GridSearchCV(estimator=ElasticNet(), param_grid=e_net, n_jobs=-1, cv=10, scoring=RMSE)
model_enet.fit(x_train_scaled, y_train)
print('Best Params:')
print(model_enet.best_params_)
print('Best CV Score(RMSE):')
print(-model_enet.best_score_)
# Out:
# ElasticNet
# Best Params:
# {'alpha': 0.0001, 'l1_ratio': 0.5}
# Best CV Score(RMSE):
# 0.19079935493611708

# %%
svr = {'C':[5,10,20], 'epsilon':[0.001, 0.01, 0.1], 'gamma':[0.0001, 0.001, 0.01]}
print("SVR")
model_svr = GridSearchCV(estimator=SVR(), param_grid=svr, n_jobs=-1, cv=10, scoring=RMSE)
model_svr.fit(x_train_scaled, y_train)
print('Best Params:')
print(model_svr.best_params_)
print('Best CV Score(RMSE):')
print(-model_svr.best_score_)
# Out:
# SVR
# /Users/anthony/miniforge3/envs/spark/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Best Params:
# {'C': 20, 'epsilon': 0.1, 'gamma': 0.01}
# Best CV Score(RMSE):
# 0.13634043848856864

# %%
gbr = {'n_estimators': [100, 1000, 5000], # default is 6
                            'learning_rate': [0.1, 0.01], # default is 0.3
                            'max_depth': [3, 4, 5], # Max Split 
                            'min_samples_leaf': [1,10,20], # If dataset is unbalanced, default is 1 
                            'min_samples_split': [2, 10, 20], # default is 0.3
                            }

print("GBR")
model_gbr = GridSearchCV(estimator=GradientBoostingRegressor(max_features='sqrt', loss='huber', random_state =42) , param_grid=gbr, n_jobs=-1, cv=10, scoring=RMSE)
model_gbr.fit(x_train_scaled, y_train)
print('Best Params:')
print(model_gbr.best_params_)
print('Best CV Score(RMSE):')
print(-model_gbr.best_score_)
# Out:
# GBR
# Best Params:
# {'learning_rate': 0.1, 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5000}
# Best CV Score(RMSE):
# 0.11162650143395711

# %%
lgbr = {'n_estimators': [100, 1000, 5000], # default is 6
        'learning_rate': [0.1, 0.01], # default is 0.3
        'num_leaves': [3, 4, 5], # Max Split 
        'max_bin': [100,200],
        'bagging_fraction': [0.5,0.75],
        'feature_fraction': [0.1,0.2,0.3],
        }

print("LGBR")
model_lgbr = GridSearchCV(estimator=lgb.LGBMRegressor(objective='regression', 
                                       bagging_freq=5, 
                                       bagging_seed=7,
                                       feature_fraction_seed=7,
                                       verbose=-1,
                                       ), param_grid=lgbr, n_jobs=-1, cv=10, scoring=RMSE)
model_lgbr.fit(x_train_scaled, y_train)
print('Best Params:')
print(model_lgbr.best_params_)
print('Best CV Score(RMSE):')
print(-model_lgbr.best_score_)
# Out:
# LGBR
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5[LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
#
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1[LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
#
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5[LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
#
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5[LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
#
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# ...
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75[LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
#
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# Best Params:
# {'bagging_fraction': 0.75, 'feature_fraction': 0.3, 'learning_rate': 0.1, 'max_bin': 200, 'n_estimators': 5000, 'num_leaves': 5}
# Best CV Score(RMSE):
# 0.11741366667773474

# %%
xgbr = {'n_estimators': [100, 1000, 5000], # default is 6
        'learning_rate': [0.1, 0.01], # default is 0.3
        'min_child_weight': [0,0.1],
        'gamma': [0,0.01],
        'subsample': [0.7, 0.9],
        'reg_alpha': [0.001,0.0001,0.00001],
        'max_depth': [3,4,5],
        'max_leaves': [10,15,20],
        }

print("XGBR")
model_xgbr = RandomizedSearchCV(XGBRegressor( 
                                     colsample_bytree=0.7,
                                     objective='reg:linear', nthread=-1,
                                     scale_pos_weight=1, seed=27),xgbr, n_iter=100, n_jobs=-1, cv=10, scoring=RMSE)
model_xgbr.fit(x_train_scaled, y_train)
print('Best Params:')
print(model_xgbr.best_params_)
print('Best CV Score(RMSE):')
print(-model_xgbr.best_score_)
# Out:
# XGBR
# [00:29:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:43] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:43] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:54] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:32:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:43] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:43] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:33:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:34:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:34:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:34:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:34:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:34:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:34:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:34:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:34:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:34:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:34:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:34:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:34:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:34:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:34:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:34:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:34:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:35:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:35:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:35:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:35:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:35:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:35:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:35:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:35:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:35:54] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:35:54] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:35:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:35:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:35:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:35:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:36:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:36:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:36:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:36:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:36:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:36:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:36:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:36:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:36:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:36:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:36:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:36:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:36:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:36:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:36:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:36:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:37:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:37:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:37:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:37:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:37:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:37:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:37:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:37:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:37:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:37:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:37:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:37:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:54] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:38:54] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:39:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:39:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:39:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:39:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:39:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [00:39:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# ...
# [01:26:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:26:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:26:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:26:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:26:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:26:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:26:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:26:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:26:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:26:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:26:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:26:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:00] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:27:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:28:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:28:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:28:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:28:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:28:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:28:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:00] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:29:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:30:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:30:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:31:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:31:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:31:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:31:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:31:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:31:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:31:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:31:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:31:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:31:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:32:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# Best Params:
# {'subsample': 0.9, 'reg_alpha': 1e-05, 'n_estimators': 5000, 'min_child_weight': 0, 'max_leaves': 10, 'max_depth': 5, 'learning_rate': 0.1, 'gamma': 0.01}
# Best CV Score(RMSE):
# 0.10881782540993827

# %% [markdown]
# Results

# %%
import pickle
# save the model to disk
filename = 'model_ridge.sav'
pickle.dump(model_ridge.best_estimator_, open(filename, 'wb'))
# save the model to disk
filename = 'model_lasso.sav'
pickle.dump(model_lasso.best_estimator_, open(filename, 'wb'))
# save the model to disk
filename = 'model_enet.sav'
pickle.dump(model_enet.best_estimator_, open(filename, 'wb'))
# save the model to disk
filename = 'model_svr.sav'
pickle.dump(model_svr.best_estimator_, open(filename, 'wb'))

### Trees

# save the model to disk
filename = 'model_lgbr.sav'
pickle.dump(model_lgbr.best_estimator_, open(filename, 'wb'))

# save the model to disk
filename = 'model_xgbr.sav'
pickle.dump(model_xgbr.best_estimator_, open(filename, 'wb'))

# save the model to disk
filename = 'model_gbr.sav'
pickle.dump(model_gbr.best_estimator_, open(filename, 'wb'))

# %%
model_ridge.best_estimator_
# Out:
# Ridge(alpha=5)

# %%
model_lasso.best_estimator_
# Out:
# Lasso(alpha=5e-05)

# %%
model_enet.best_estimator_
# Out:
# ElasticNet(alpha=0.0001)

# %%
model_svr.best_estimator_
# Out:
# SVR(C=20, gamma=0.01)

# %%
model_lgbr.best_estimator_
# Out:
# LGBMRegressor(bagging_fraction=0.75, bagging_freq=5, bagging_seed=7,
#               feature_fraction=0.2, feature_fraction_seed=7, max_bin=200,
#               n_estimators=5000, num_leaves=5, objective='regression',
#               verbose=-1)

# %%
model_gbr.best_estimator_
# Out:
# GradientBoostingRegressor(loss='huber', max_depth=4, max_features='sqrt',
#                           n_estimators=5000, random_state=42)

# %%
model_xgbr.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.7,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0.01, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.1, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=5, max_leaves=10, min_child_weight=0,
#              missing=nan, monotone_constraints='()', n_estimators=5000,
#              n_jobs=-1, nthread=-1, num_parallel_tree=1, objective='reg:linear',
#              predictor='auto', random_state=27, ...)

# %% [markdown]
# #### Stacking
# - Implement use of http://rasbt.github.io/mlxtend/user_guide/regressor/StackingCVRegressor/

# %%
stack_gen = StackingCVRegressor(regressors=(model_ridge.best_estimator_, model_lasso.best_estimator_, model_enet.best_estimator_, model_gbr.best_estimator_, model_xgbr.best_estimator_, model_lgbr.best_estimator_),
                                meta_regressor=model_xgbr,
                                use_features_in_secondary=True, n_jobs=-1, cv=10)

# %%
stack_gen = StackingCVRegressor(regressors=(model_ridge, model_lasso, model_enet, model_gbr, model_xgbr, model_lgbr),
                                meta_regressor=model_xgbr,
                                use_features_in_secondary=True, n_jobs=-1, cv=5)

# %%
print('START Fit')

print('stack_gen')
# stack_gen_model = stack_gen.fit(np.array(x_train_scaled), np.array(y_train))
stack_gen_model = stack_gen.fit(x_train_scaled, y_train)


print('lightgbm')
lgb_model_full_data = model_lgbr.best_estimator_.fit(x_train_scaled, y_train)
# Out:
# START Fit
# stack_gen
# [14:26:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:26:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:26:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:26:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:26:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:26:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:26:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:26:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:27:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:27:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [14:28:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:28:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:28:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:28:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:28:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:28:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:28:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:28:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:29:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:29:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:29:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:29:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:29:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:29:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:29:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:29:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:30:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:30:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:30:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:30:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:30:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:30:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:30:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:30:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:31:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:31:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:31:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:31:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:31:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:31:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:31:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:31:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:31:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:31:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:31:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:31:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:31:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:23] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:32:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:33:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# /Users/anthony/miniforge3/envs/spark/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [14:34:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:43] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:23] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:23] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:35:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:37:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:37:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:37:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:37:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:38:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:38:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:38:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:38:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:38:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:38:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:38:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [14:38:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# ...
# [15:41:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:54] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:43] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:23] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:23] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:23] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:23] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# lightgbm

# %%
print('elasticnet')
elastic_model_full_data = model_enet.best_estimator_.fit(x_train_scaled, y_train)

print('Lasso')
lasso_model_full_data = model_lasso.best_estimator_.fit(x_train_scaled, y_train)

print('Ridge')
ridge_model_full_data = model_ridge.best_estimator_.fit(x_train_scaled, y_train)

print('Svr')
svr_model_full_data = model_svr.best_estimator_.fit(x_train_scaled, y_train)

print('GradientBoosting')
gbr_model_full_data = model_gbr.best_estimator_.fit(x_train_scaled, y_train)

print('xgboost')
xgb_model_full_data = model_xgbr.best_estimator_.fit(x_train_scaled, y_train)

print('lightgbm')
lgb_model_full_data = model_lgbr.best_estimator_.fit(x_train_scaled, y_train)
# Out:
# START Fit
# stack_gen
# [01:40:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.[01:40:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:40:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
#
# [01:40:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:40:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2[LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
#
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [01:41:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [01:44:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# elasticnet
# Lasso
# Ridge
# Svr
# GradientBoosting
# xgboost
# [01:46:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# lightgbm

# %%
filename = 'stack_gen_model.sav'
pickle.dump(stack_gen_model, open(filename, 'wb'))

# %%
# Single Model Scoring

print(f"Ridge: {-model_ridge.best_score_} (RMSE)")
print(f"LASSO: {-model_lasso.best_score_} (RMSE)")
print(f"ElasticNet: {-model_enet.best_score_} (RMSE)")
# score = cv_rmse(model_svr.best_estimator_.best_estimator__svr, x_train_scaled, y_train)
score = cv_rmse(model_svr.best_estimator_,x_train_scaled, y_train)
print("SVR: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
score = cv_rmse(model_lgbr.best_estimator_,x_train_scaled, y_train)
print("LGBR: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
score = cv_rmse(model_gbr.best_estimator_,x_train_scaled, y_train)
print("GBR: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# score = cv_rmse(model_xgbr.best_estimator_,x_train_scaled, y_train)
# print("XGBR: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# score = cv_rmse(stack_gen_model,x_train_scaled, y_train)
# print("Stacking: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))

# print(f"SVR: {rmse_pred(y_train, model_svr.best_estimator_.predict(x_train_scaled))} (RMSE)")
# print(f"LGBR: {rmse_pred(y_train, model_lgbr.predict(x_train_scaled))} (RMSE)")
# print(f"GBR: {rmse_pred(y_train, model_gbr.predict(x_train_scaled))} (RMSE)")
# print(f"XGBR: {rmse_pred(y_train, model_xgbr.predict(x_train_scaled))} (RMSE)")
# print(f"Stacking: {rmse_pred(y_train, stack_gen_model.predict(x_train_scaled))} (RMSE)")

# # score = cv_rmse(model_lgbr.best_estimator_, x_train_scaled, y_train)
# score = np.sqrt(-cross_val_score(model_lgbr.best_estimator_,x_train_scaled, y_train, scoring="neg_mean_squared_error", cv=5, n_jobs=-1))
# print("lightgbm: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))

# # score = cv_rmse(model_gbr.best_estimator_, x_train_scaled, y_train)
# score = np.sqrt(-cross_val_score(model_gbr.best_estimator_,x_train_scaled, y_train, scoring="neg_mean_squared_error", cv=5, n_jobs=-1))
# print("gbr: {:.4f} ({:.4f})\n".format(score.mean(), score.std()) )

# # score = cv_rmse(model_xgbr.best_estimator_, x_train_scaled, y_train)
# score = np.sqrt(-cross_val_score(model_xgbr.best_estimator_,x_train_scaled, y_train, scoring="neg_mean_squared_error", cv=5, n_jobs=-1))
# print("xgboost: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))

# print(f"SVR: {rmse_pred(y_train, stack_gen_model.predict(x_train_scaled))} (RMSE)")
# Out:
# Ridge: 0.19094206104652497 (RMSE)
# LASSO: 0.19078170841568592 (RMSE)
# ElasticNet: 0.19079935493611708 (RMSE)
# SVR: 0.1382 (0.0024)
#
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# LGBR: 0.1196 (0.0038)
#
# GBR: 0.1169 (0.0080)
#
# [16:02:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.[16:02:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
#
# [16:02:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:02:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:02:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# XGBR: 0.1128 (0.0056)
# [16:10:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:10:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:10:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:10:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:10:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:10:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:10:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:10:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:11:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:12:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:12:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:12:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:12:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:12:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:12:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:12:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:12:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:15:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:15:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:16:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:16:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:17:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:17:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:17:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:17:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:17:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:17:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [16:18:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:18:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:18:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:18:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:18:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:18:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:18:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:18:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:18:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:18:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:18:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:18:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:18:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:18:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:18:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:18:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [16:19:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [16:19:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [16:19:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [16:19:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:19:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [16:20:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:20:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# ...
# [16:50:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:50:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:50:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:50:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:50:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:51:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:51:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:51:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:51:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:51:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:51:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:52:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:52:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:52:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:52:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:52:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:52:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:52:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:52:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:52:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:53:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:53:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:53:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:53:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:43] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:55:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:55:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:55:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:56:54] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:56:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:57:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:57:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:57:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:57:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [2267], line 15
#      13 score = cv_rmse(model_xgbr.best_estimator_,x_train_scaled, y_train)
#      14 print("XGBR: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# ---> 15 score = cv_rmse(stack_gen_model,x_train_scaled, y_train)
#      16 print("Stacking: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
#
# Cell In [2215], line 13, in cv_rmse(clf, x, y)
#      12 def cv_rmse(clf, x, y):
# ---> 13     rmse = np.sqrt(-cross_val_score(clf, x, y, scoring="neg_mean_squared_error", cv=5, n_jobs=-1))
#      14     return (rmse)
#
# File ~/miniforge3/envs/spark/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:515, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     512 # To ensure multimetric format is not supported
#     513 scorer = check_scoring(estimator, scoring=scoring)
# --> 515 cv_results = cross_validate(
#     516     estimator=estimator,
#     517     X=X,
#     518     y=y,
#     519     groups=groups,
#     520     scoring={"score": scorer},
#     521     cv=cv,
#     522     n_jobs=n_jobs,
#     523     verbose=verbose,
#     524     fit_params=fit_params,
#     525     pre_dispatch=pre_dispatch,
#     526     error_score=error_score,
#     527 )
#     528 return cv_results["test_score"]
#
# File ~/miniforge3/envs/spark/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:266, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     263 # We clone the estimator to make sure that all the folds are
#     264 # independent, and that it is pickle-able.
#     265 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 266 results = parallel(
#     267     delayed(_fit_and_score)(
#     268         clone(estimator),
#     269         X,
#     270         y,
#     271         scorers,
#     272         train,
#     273         test,
#     274         verbose,
#     275         None,
#     276         fit_params,
#     277         return_train_score=return_train_score,
#     278         return_times=True,
#     279         return_estimator=return_estimator,
#     280         error_score=error_score,
#     281     )
#     282     for train, test in cv.split(X, y, groups)
#     283 )
#     285 _warn_or_raise_about_fit_failures(results, error_score)
#     287 # For callabe scoring, the return type is only know after calling. If the
#     288 # return type is a dictionary, the error scores can now be inserted with
#     289 # the correct key.
#
# File ~/miniforge3/envs/spark/lib/python3.8/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/miniforge3/envs/spark/lib/python3.8/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~/miniforge3/envs/spark/lib/python3.8/site-packages/joblib/_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File ~/miniforge3/envs/spark/lib/python3.8/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     436 elif self._state == FINISHED:
#     437     return self.__get_result()
# --> 439 self._condition.wait(timeout)
#     441 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     442     raise CancelledError()
#
# File ~/miniforge3/envs/spark/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:

# %%
score = cv_rmse(model_xgbr.best_estimator_,x_train_scaled, y_train)
print("XGBR: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# [16:58:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:58:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:58:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:58:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:58:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# XGBR: 0.1128 (0.0056)

# %%
score = cv_rmse(stack_gen_model,x_train_scaled, y_train)
print("Stacking: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# [17:07:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:08:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:08:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:08:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:08:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:08:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.[17:08:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
#
# [17:08:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:08:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:08:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:08:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:08:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:08:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:08:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:08:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:08:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:08:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:13:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:13:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:13:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:13:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [17:16:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [17:16:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [17:16:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [17:16:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:16:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:17:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:17:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:17:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:17:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:17:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:17:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:17:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:17:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:17:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:17:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:17:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:18:00] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:18:00] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:18:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:18:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:18:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:18:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:18:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:18:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:18:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:18:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:18:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# ...
# [17:30:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:30:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:31:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:31:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:31:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:31:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:31:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:31:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:31:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:31:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:31:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:31:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:31:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:31:43] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:31:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:31:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:31:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:31:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:31:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:32:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:32:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:32:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:32:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:32:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:32:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:32:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:32:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:32:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:32:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:32:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:32:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:32:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:32:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:32:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:32:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [2269], line 1
# ----> 1 score = cv_rmse(stack_gen_model,x_train_scaled, y_train)
#       2 print("Stacking: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
#
# Cell In [2215], line 13, in cv_rmse(clf, x, y)
#      12 def cv_rmse(clf, x, y):
# ---> 13     rmse = np.sqrt(-cross_val_score(clf, x, y, scoring="neg_mean_squared_error", cv=5, n_jobs=-1))
#      14     return (rmse)
#
# File ~/miniforge3/envs/spark/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:515, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     512 # To ensure multimetric format is not supported
#     513 scorer = check_scoring(estimator, scoring=scoring)
# --> 515 cv_results = cross_validate(
#     516     estimator=estimator,
#     517     X=X,
#     518     y=y,
#     519     groups=groups,
#     520     scoring={"score": scorer},
#     521     cv=cv,
#     522     n_jobs=n_jobs,
#     523     verbose=verbose,
#     524     fit_params=fit_params,
#     525     pre_dispatch=pre_dispatch,
#     526     error_score=error_score,
#     527 )
#     528 return cv_results["test_score"]
#
# File ~/miniforge3/envs/spark/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:266, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     263 # We clone the estimator to make sure that all the folds are
#     264 # independent, and that it is pickle-able.
#     265 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 266 results = parallel(
#     267     delayed(_fit_and_score)(
#     268         clone(estimator),
#     269         X,
#     270         y,
#     271         scorers,
#     272         train,
#     273         test,
#     274         verbose,
#     275         None,
#     276         fit_params,
#     277         return_train_score=return_train_score,
#     278         return_times=True,
#     279         return_estimator=return_estimator,
#     280         error_score=error_score,
#     281     )
#     282     for train, test in cv.split(X, y, groups)
#     283 )
#     285 _warn_or_raise_about_fit_failures(results, error_score)
#     287 # For callabe scoring, the return type is only know after calling. If the
#     288 # return type is a dictionary, the error scores can now be inserted with
#     289 # the correct key.
#
# File ~/miniforge3/envs/spark/lib/python3.8/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/miniforge3/envs/spark/lib/python3.8/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~/miniforge3/envs/spark/lib/python3.8/site-packages/joblib/_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File ~/miniforge3/envs/spark/lib/python3.8/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     436 elif self._state == FINISHED:
#     437     return self.__get_result()
# --> 439 self._condition.wait(timeout)
#     441 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     442     raise CancelledError()
#
# File ~/miniforge3/envs/spark/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:

# %%
print(f"Stacking: {rmse_pred(y_train, stack_gen_model.predict(x_train_scaled))} (RMSE)")

# score = cv_rmse(stack_gen_model,x_train_scaled, y_train)
# print("Stacking: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Stacking: 0.052258926191401246 (RMSE)

# %% [markdown]
# #### Blending Models / "Ensambling"

# %%
def blend_models_predict(X):
    return ((0.1 * elastic_model_full_data.predict(X)) + \
            (0.1 * lasso_model_full_data.predict(X)) + \
            (0.1 * ridge_model_full_data.predict(X)) + \
            (0.1 * svr_model_full_data.predict(X)) + \
            (0.1 * gbr_model_full_data.predict(X)) + \
            (0.1 * xgb_model_full_data.predict(X)) + \
            (0.1 * lgb_model_full_data.predict(X)) + \
            (0.3 * stack_gen_model.predict(X)))

# %%
print('RMSE score on train data:')
train_pred = blend_models_predict(x_train_scaled)
print(rmse_pred(y_train, train_pred))
print('R-Squared score on train data:')
print(rsq_pred(y_train, train_pred))
# Out:
# RMSE score on train data:
# 0.08954526833463916
# R-Squared score on train data:
# 0.9866396316241358

# %%
train_normal_price = df_train['price']
print('RMSE score, normal price, on train data:')
train_norm_pred = np.expm1(blend_models_predict(x_train_scaled))
print(rmse_pred(train_normal_price, train_norm_pred))
print('R-Squared, normal price, score on train data:')
print(rsq_pred(train_normal_price, train_norm_pred))
# Out:
# RMSE score, normal price, on train data:
# 355189.00577204576
# R-Squared, normal price, score on train data:
# 0.9702336244940687

# %% [markdown]
# Prediction on test data

# %%
test_price = pd.read_csv('test_realprice.csv')

# %%
test_scaled = all_ct_pipeline.fit_transform(test)
test_scaled.shape
# Out:
# (6012, 65)

# %%
print('predict on test data')
results = np.expm1(blend_models_predict(test_scaled))
# Out:
# predict on test data

# %%
from numpy import savetxt

savetxt('results.csv', results)

# %%
landed_test_price = test_price[test_price.index.isin(test.index)].Predicted

# %%
print('RMSE score on test data:')
print(rmse_pred(landed_test_price, results.astype(int)))
print('R-Squared score on test data:')
print(rsq_pred(landed_test_price, results.astype(int)))
# Out:
# RMSE score on test data:
# 1600670.9978524116
# R-Squared score on test data:
# 0.7195031336475645

# %% [markdown]
# # Archive

# %%
alphas_alt = {'alphas_alt':[5,10,15,20]}
alphas2 = {'alphas2':[5e-05, 0.0001, 0.001, 0.01]}
e_net = {'alphas':[0.0001, 0.001, 0.01], 'l1_ratio': [0.5,0.8,1.0]}
svr = {'C':[5,10,20], 'epsilon':[0.001, 0.01, 0.1], 'gamma':[0.0001, 0.001, 0.01]}

# %%
alphas_alt = [14.5, 14.6, 14.7, 14.8, 14.9, 15, 15.1, 15.2, 15.3, 15.4, 15.5]
alphas2 = [5e-05, 0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008]
e_alphas = [0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007]
e_l1ratio = [0.8, 0.85, 0.9, 0.95, 0.99, 1]
ridge = make_pipeline(RobustScaler(), RidgeCV(alphas=alphas_alt, cv=kfolds))
lasso = make_pipeline(RobustScaler(), LassoCV(max_iter=1e7, alphas=alphas2, random_state=42, cv=kfolds))
elasticnet = make_pipeline(RobustScaler(), ElasticNetCV(max_iter=1e7, alphas=e_alphas, cv=kfolds, l1_ratio=e_l1ratio))                                
svr = make_pipeline(RobustScaler(), SVR(C= 20, epsilon= 0.008, gamma=0.0003,))
alphas_alt = [14.5, 14.6, 14.7, 14.8, 14.9, 15, 15.1, 15.2, 15.3, 15.4, 15.5]
alphas2 = [5e-05, 0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008]
e_alphas = [0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007]
e_l1ratio = [0.8, 0.85, 0.9, 0.95, 0.99, 1]

ridge = make_pipeline(RobustScaler(), RidgeCV(alphas=alphas_alt, cv=kfolds))
lasso = make_pipeline(RobustScaler(), LassoCV(max_iter=1e7, alphas=alphas2, random_state=42, cv=kfolds))
elasticnet = make_pipeline(RobustScaler(), ElasticNetCV(max_iter=1e7, alphas=e_alphas, cv=kfolds, l1_ratio=e_l1ratio))                                
svr = make_pipeline(RobustScaler(), SVR(C= 20, epsilon= 0.008, gamma=0.0003,))
gbr = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05, max_depth=4, max_features='sqrt', min_samples_leaf=15, min_samples_split=10, loss='huber', random_state =42)                             
lightgbm = lgb.LGBMRegressor(objective='regression', 
                                       num_leaves=4,
                                       learning_rate=0.01, 
                                       n_estimators=5000,
                                       max_bin=200, 
                                       bagging_fraction=0.75,
                                       bagging_freq=5, 
                                       bagging_seed=7,
                                       feature_fraction=0.2,
                                       feature_fraction_seed=7,
                                       verbose=-1,
                                       )

xgboost = XGBRegressor(learning_rate=0.01,n_estimators=3460,
                                     max_depth=3, min_child_weight=0,
                                     gamma=0, subsample=0.7,
                                     colsample_bytree=0.7,
                                     objective='reg:linear', nthread=-1,
                                     scale_pos_weight=1, seed=27,
                                     reg_alpha=0.00006)

# Using various prediction models that we just created 
score = cv_rmse(ridge, x_train_scaled, y_train)
score = cv_rmse(lasso, x_train_scaled, y_train)
print("LASSO: {:.4f} ({:.4f})\n".format(score.mean(), score.std()), datetime.now(), )

score = cv_rmse(elasticnet)
print("elastic net: {:.4f} ({:.4f})\n".format(score.mean(), score.std()), datetime.now(), )

score = cv_rmse(svr)
print("SVR: {:.4f} ({:.4f})\n".format(score.mean(), score.std()), datetime.now(), )

score = cv_rmse(lightgbm)
print("lightgbm: {:.4f} ({:.4f})\n".format(score.mean(), score.std()), datetime.now(), )

score = cv_rmse(gbr)
print("gbr: {:.4f} ({:.4f})\n".format(score.mean(), score.std()), datetime.now(), )

score = cv_rmse(xgboost)
print("xgboost: {:.4f} ({:.4f})\n".format(score.mean(), score.std()), datetime.now(), )
#### Stacking
- Implement use of http://rasbt.github.io/mlxtend/user_guide/regressor/StackingCVRegressor/
stack_gen = StackingCVRegressor(regressors=(ridge, lasso, elasticnet, gbr, xgboost, lightgbm),
                                meta_regressor=xgboost,
                                use_features_in_secondary=True)

print('START Fit')

print('stack_gen')
stack_gen_model = stack_gen.fit(np.array(x_train_scaled), np.array(y_train))

print('elasticnet')
elastic_model_full_data = elasticnet.fit(x_train_scaled, y_train)

print('Lasso')
lasso_model_full_data = lasso.fit(x_train_scaled, y_train)

print('Ridge')
ridge_model_full_data = ridge.fit(x_train_scaled, y_train)

print('Svr')
svr_model_full_data = svr.fit(x_train_scaled, y_train)

print('GradientBoosting')
gbr_model_full_data = gbr.fit(x_train_scaled, y_train)

print('xgboost')
xgb_model_full_data = xgboost.fit(x_train_scaled, y_train)

print('lightgbm')
lgb_model_full_data = lightgbm.fit(x_train_scaled, y_train)

#### Blending Models / "Ensambling"
def blend_models_predict(X):
    return ((0.1 * elastic_model_full_data.predict(X)) + \
            (0.05 * lasso_model_full_data.predict(X)) + \
            (0.1 * ridge_model_full_data.predict(X)) + \
            (0.1 * svr_model_full_data.predict(X)) + \
            (0.1 * gbr_model_full_data.predict(X)) + \
            (0.15 * xgb_model_full_data.predict(X)) + \
            (0.1 * lgb_model_full_data.predict(X)) + \
            (0.3 * stack_gen_model.predict(np.array(X))))

print('RMSE score on train data:')
print(rmse_pred(y_train, blend_models_predict(x_train_scaled)))
print('R-Squared score on train data:')
print(rsq_pred(y_train, blend_models_predict(x_train_scaled)))
print('predict on test data:')
np.expm1(blend_models_predict(test))

# %% [markdown]
# # PREVIOUS WORK

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numeric_features = x_train.select_dtypes(include=numerics).columns

# %%
numeric_transformer = Pipeline(
    steps=[("scaler", StandardScaler())]
)

# %%
categorial = ['object']
categorical_features = x_train.select_dtypes(include=categorial).columns

# %%
categorical_transformer = ce.OneHotEncoder(handle_unknown="ignore")

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score

def get_PR_AUC(clf, x, y):
    
    avg_precision = cross_val_score(clf, x, y, scoring="neg_mean_squared_error", cv=5, n_jobs=-1).mean()
    return (avg_precision)

# %% [markdown]
# ### LightGBM

# %%
clf = Pipeline(
    steps=[("preprocessor", preprocessor), ("classifier", lgb.LGBMClassifier())]
)

param_grid = {'preprocessor__num__scaler': [StandardScaler(), MinMaxScaler(), RobustScaler(), MaxAbsScaler()], 
              'classifier__n_estimators': list(range(15,30,5)),
              'classifier__learning_rate': [0.01,0.05, 0.1],
              'classifier__max_depth': list(range(1,4,1))
}

# %%
grid_LGB = GridSearchCV(clf, param_grid, cv = 5, scoring = 'neg_mean_squared_error', verbose = 2, n_jobs=-1) 


grid_LGB.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 3.1min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 3.1min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 3.1min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 2.8min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.8min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.8min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 3.7min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 3.7min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 3.7min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 3.8min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.6min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 4.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 4.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 4.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 4.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 4.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 4.6min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 4.7min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 4.8min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 4.6min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 4.7min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 4.7min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 4.7min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 4.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 4.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 4.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 4.1min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.7min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 4.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 4.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 4.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 2.6min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 2.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 3.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 3.1min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.1min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.6min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 3.6min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 3.6min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 3.7min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 3.7min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 3.6min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 4.0min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 3.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 3.6min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 3.7min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 3.7min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 7.1min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 7.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 8.1min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 8.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 8.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 8.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 8.0min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 8.0min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 4.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 4.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 4.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 4.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 4.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 4.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 4.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 4.6min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 4.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 4.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 4.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 6.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 5.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 5.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 6.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 6.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 4.9min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 4.9min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 4.9min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 3.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 3.6min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 3.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 4.0min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 4.6min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time=17.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time=17.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time=17.1min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time=17.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time=17.1min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time=17.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time=16.7min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time=16.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 4.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 4.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 4.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 4.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 5.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 4.9min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 4.1min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 4.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 4.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 4.3min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 5.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 5.7min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 5.5min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 5.6min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 5.8min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 5.6min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 5.7min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 5.7min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 5.8min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 6.2min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 6.9min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 6.0min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 5.7min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 5.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 5.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 5.2min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 2.2min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 2.7min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 5.3min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 2.4min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 2.5min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 2.4min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 5.8min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 5.9min
# [CV] END classifier__learning_rate=0.01, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 5.8min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 2.2min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 2.5min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 2.4min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time=32.4min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time=32.6min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time=33.3min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time=33.7min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time=34.1min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time=34.6min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time=48.7min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time=48.8min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time=18.7min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time=19.0min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time=17.9min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time=17.4min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time=18.1min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time=17.3min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 2.7min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 2.7min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 2.7min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 2.6min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 2.7min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.8min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.6min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.8min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.1min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.6min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.6min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.7min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.6min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.6min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 3.5min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 3.9min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 1.9min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.5min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 2.0min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 1.9min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=1, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.7min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 2.2min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 1.8min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 1.8min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 1.9min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 1.8min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 2.0min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 1.9min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 2.1min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 1.9min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 2.0min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 2.4min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 8.1min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 8.2min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 8.0min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 8.3min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 8.4min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 8.3min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 8.7min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 8.1min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 2.6min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 2.5min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 2.5min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 2.5min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 2.5min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 2.5min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 2.5min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 2.6min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 2.3min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 2.5min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 2.5min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 2.2min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 2.5min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.6min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.7min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.3min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.6min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.6min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.1min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.1min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.1min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.1min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.6min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 3.6min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 3.6min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 6.9min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 7.1min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 7.4min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 6.0min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 7.4min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 6.2min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 7.6min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 7.4min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 2.7min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 2.7min
# [CV] END classifier__learning_rate=0.05, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 2.6min
# ...
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 2.7min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 2.7min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 2.6min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 2.7min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 2.8min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 2.6min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 2.5min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 2.8min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.6min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.5min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.5min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.6min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.6min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.1min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 3.1min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 3.3min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 3.1min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.1min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 2.2min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 2.2min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 2.1min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 2.2min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=StandardScaler(); total time= 2.0min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 2.2min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 2.3min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 2.3min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 2.3min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MinMaxScaler(); total time= 2.4min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 2.3min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 2.4min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 2.3min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 2.1min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=RobustScaler(); total time= 2.2min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.0min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.1min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.6min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.1min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=15, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.1min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 2.8min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=StandardScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 3.1min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 2.8min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MinMaxScaler(); total time= 2.5min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 2.7min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 2.7min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=RobustScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.7min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.7min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=20, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.6min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.6min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.7min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.8min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=StandardScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.5min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.6min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.7min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.1min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MinMaxScaler(); total time= 3.6min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 3.2min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 3.5min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 4.2min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.4min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=RobustScaler(); total time= 3.5min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.9min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.0min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 2.8min
# [CV] END classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=25, preprocessor__num__scaler=MaxAbsScaler(); total time= 3.2min
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          Index(['built_year', 'num_beds', 'num_baths', 'available_unit_types',
#        'total_num_units', 'cc_distance', 'mrt_distance',
#        'primary_school_distance', 'secondary_school_distance', 'shop_distance',
#        'population', 'area_siz...
#                                                                          Index(['property_type', 'tenure', 'furnishing', 'region'], dtype='object'))])),
#                                        ('classifier', LGBMClassifier())]),
#              n_jobs=-1,
#              param_grid={'classifier__learning_rate': [0.01, 0.05, 0.1],
#                          'classifier__max_depth': [1, 2, 3],
#                          'classifier__n_estimators': [15, 20, 25],
#                          'preprocessor__num__scaler': [StandardScaler(),
#                                                        MinMaxScaler(),
#                                                        RobustScaler(),
#                                                        MaxAbsScaler()]},
#              scoring='neg_mean_squared_error', verbose=2)

# %%
grid_LGB.best_params_
# Out:
# {'classifier__learning_rate': 0.01,
#  'classifier__max_depth': 2,
#  'classifier__n_estimators': 25,
#  'preprocessor__num__scaler': StandardScaler()}

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rf = Pipeline(
    steps=[("preprocessor", preprocessor), ("classifier", RandomForestRegressor(random_state=2022))]
)

param_grid = {'preprocessor__num__scaler': [StandardScaler(), MinMaxScaler(), RobustScaler(), MaxAbsScaler()], 
              'classifier__n_estimators': list(range(50,150,50)),
              'classifier__min_samples_split': list(range(2,6,2)),
              'classifier__min_samples_leaf': list(range(1,4,1)),
              'classifier__max_depth': list(range(1,4,1)),
              'classifier__criterion': ['squared_error','absolute_error','poisson']
}

# %%
random_rf = RandomizedSearchCV(rf, param_grid, cv = 5, scoring = 'neg_mean_squared_error', verbose = 2, n_jobs=-1) 

random_rf.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END classifier__criterion=squared_error, classifier__max_depth=3, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=100, preprocessor__num__scaler=StandardScaler(); total time=   4.6s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=3, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=100, preprocessor__num__scaler=StandardScaler(); total time=   4.8s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=3, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=100, preprocessor__num__scaler=StandardScaler(); total time=   4.9s
# [CV] END classifier__criterion=poisson, classifier__max_depth=1, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=100, preprocessor__num__scaler=MinMaxScaler(); total time=   2.3s
# [CV] END classifier__criterion=poisson, classifier__max_depth=1, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=100, preprocessor__num__scaler=MinMaxScaler(); total time=   2.2s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=3, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=100, preprocessor__num__scaler=StandardScaler(); total time=   4.8s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=3, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=100, preprocessor__num__scaler=StandardScaler(); total time=   4.9s
# [CV] END classifier__criterion=poisson, classifier__max_depth=1, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=100, preprocessor__num__scaler=MinMaxScaler(); total time=   2.3s
# [CV] END classifier__criterion=poisson, classifier__max_depth=1, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=100, preprocessor__num__scaler=MinMaxScaler(); total time=   2.2s
# [CV] END classifier__criterion=poisson, classifier__max_depth=1, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=100, preprocessor__num__scaler=MinMaxScaler(); total time=   2.3s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=1, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=50, preprocessor__num__scaler=StandardScaler(); total time=   1.2s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=1, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=50, preprocessor__num__scaler=StandardScaler(); total time=   1.2s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=1, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=50, preprocessor__num__scaler=StandardScaler(); total time=   1.2s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=1, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=50, preprocessor__num__scaler=StandardScaler(); total time=   1.2s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=1, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=50, preprocessor__num__scaler=StandardScaler(); total time=   1.1s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=1, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=MinMaxScaler(); total time=   1.1s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=1, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=MinMaxScaler(); total time=   1.1s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=1, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=MinMaxScaler(); total time=   1.1s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=1, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=MinMaxScaler(); total time=   1.1s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=1, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=MinMaxScaler(); total time=   1.1s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=MaxAbsScaler(); total time=   2.5s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=MaxAbsScaler(); total time=   2.5s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=MaxAbsScaler(); total time=   2.5s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=MaxAbsScaler(); total time=   2.5s
# [CV] END classifier__criterion=squared_error, classifier__max_depth=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=MaxAbsScaler(); total time=   2.6s
# [CV] END classifier__criterion=poisson, classifier__max_depth=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=StandardScaler(); total time=   3.0s
# [CV] END classifier__criterion=poisson, classifier__max_depth=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=StandardScaler(); total time=   3.2s
# [CV] END classifier__criterion=poisson, classifier__max_depth=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=StandardScaler(); total time=   3.2s
# [CV] END classifier__criterion=poisson, classifier__max_depth=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=StandardScaler(); total time=   3.3s
# [CV] END classifier__criterion=poisson, classifier__max_depth=1, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=100, preprocessor__num__scaler=RobustScaler(); total time=   2.8s
# [CV] END classifier__criterion=poisson, classifier__max_depth=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=StandardScaler(); total time=   3.4s
# [CV] END classifier__criterion=poisson, classifier__max_depth=1, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=100, preprocessor__num__scaler=RobustScaler(); total time=   2.6s
# [CV] END classifier__criterion=poisson, classifier__max_depth=1, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=100, preprocessor__num__scaler=RobustScaler(); total time=   2.3s
# [CV] END classifier__criterion=poisson, classifier__max_depth=1, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=100, preprocessor__num__scaler=RobustScaler(); total time=   2.4s
# [CV] END classifier__criterion=poisson, classifier__max_depth=1, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=100, preprocessor__num__scaler=RobustScaler(); total time=   2.4s
# [CV] END classifier__criterion=absolute_error, classifier__max_depth=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=100, preprocessor__num__scaler=MaxAbsScaler(); total time=25.4min
# [CV] END classifier__criterion=absolute_error, classifier__max_depth=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=100, preprocessor__num__scaler=MaxAbsScaler(); total time=25.7min
# [CV] END classifier__criterion=absolute_error, classifier__max_depth=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=100, preprocessor__num__scaler=MaxAbsScaler(); total time=25.7min
# [CV] END classifier__criterion=absolute_error, classifier__max_depth=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=100, preprocessor__num__scaler=MaxAbsScaler(); total time=25.7min
# [CV] END classifier__criterion=absolute_error, classifier__max_depth=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=100, preprocessor__num__scaler=MaxAbsScaler(); total time=25.9min
# [CV] END classifier__criterion=absolute_error, classifier__max_depth=3, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100, preprocessor__num__scaler=MinMaxScaler(); total time=25.6min
# [CV] END classifier__criterion=absolute_error, classifier__max_depth=3, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100, preprocessor__num__scaler=MinMaxScaler(); total time=25.7min
# [CV] END classifier__criterion=absolute_error, classifier__max_depth=3, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100, preprocessor__num__scaler=MinMaxScaler(); total time=25.7min
# [CV] END classifier__criterion=absolute_error, classifier__max_depth=1, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=MaxAbsScaler(); total time= 5.9min
# [CV] END classifier__criterion=absolute_error, classifier__max_depth=1, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=MaxAbsScaler(); total time= 5.9min
# [CV] END classifier__criterion=absolute_error, classifier__max_depth=1, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=MaxAbsScaler(); total time= 5.8min
# [CV] END classifier__criterion=absolute_error, classifier__max_depth=1, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=MaxAbsScaler(); total time= 5.7min
# [CV] END classifier__criterion=absolute_error, classifier__max_depth=1, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=50, preprocessor__num__scaler=MaxAbsScaler(); total time= 5.7min
# [CV] END classifier__criterion=absolute_error, classifier__max_depth=3, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100, preprocessor__num__scaler=MinMaxScaler(); total time=16.8min
# [CV] END classifier__criterion=absolute_error, classifier__max_depth=3, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100, preprocessor__num__scaler=MinMaxScaler(); total time=16.9min
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('num',
#                                                                                Pipeline(steps=[('scaler',
#                                                                                                 StandardScaler())]),
#                                                                                Index(['built_year', 'num_beds', 'num_baths', 'available_unit_types',
#        'total_num_units', 'cc_distance', 'mrt_distance',
#        'primary_school_distance', 'secondary_school_distance', 'shop_distance',
#        'population', 'ar...
#                    param_distributions={'classifier__criterion': ['squared_error',
#                                                                   'absolute_error',
#                                                                   'poisson'],
#                                         'classifier__max_depth': [1, 2, 3],
#                                         'classifier__min_samples_leaf': [1, 2,
#                                                                          3],
#                                         'classifier__min_samples_split': [2, 4],
#                                         'classifier__n_estimators': [50, 100],
#                                         'preprocessor__num__scaler': [StandardScaler(),
#                                                                       MinMaxScaler(),
#                                                                       RobustScaler(),
#                                                                       MaxAbsScaler()]},
#                    scoring='neg_mean_squared_error', verbose=2)

# %%
random_rf.best_params_
# Out:
# {'preprocessor__num__scaler': StandardScaler(),
#  'classifier__n_estimators': 100,
#  'classifier__min_samples_split': 4,
#  'classifier__min_samples_leaf': 2,
#  'classifier__max_depth': 3,
#  'classifier__criterion': 'squared_error'}

# %%
random_rf.best_score_
# Out:
# -2315989530415.111

# %% [markdown]
# # Final Model

# %%
final_model = random_rf.best_estimator_

# %%
final_model.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['built_year', 'num_beds', 'num_baths', 'available_unit_types',
#        'total_num_units', 'cc_distance', 'mrt_distance',
#        'primary_school_distance', 'secondary_school_distance', 'shop_distance',
#        'population', 'area_size', 'log_size_sqft'],
#       dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['property_type', 'tenure', 'furnishing', 'region'], dtype='object'))])),
#                 ('classifier',
#                  RandomForestRegressor(max_depth=3, min_samples_leaf=2,
#                                        min_samples_split=4,
#                                        random_state=2022))])

# %%
predicted = final_model.predict(test)

# %%
predictions_df=pd.DataFrame(data={"Predicted":predicted})

# %%
#export as csv
predictions_df.to_csv('pred.csv', index_label = 'Id')
